# %%
# %matplotlib inline
import pandas as pd
import os
import numpy as np
import math
import csv
import pickle
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy import stats
import seaborn as sns
from pylab import rcParams
import tqdm
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from Model import AccExtractor, AccClassifier
from matplotlib.lines import Line2D   
from tqdm import tqdm
import tqdm
    
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 14, 8

# %% [markdown]
# ### Select Sources and Targets

# %%
source_one = 2
source_two = 4
selected_Target = 1
selected_user = 4

# %%
save_path = "/home/avijoychakma/Downloads/DTCN-AR/Dataset Preprocessing/OPPORTUNITY/ACC-Position-Preprocessed/"
pth_path = "/home/avijoychakma/Downloads/DTCN-AR/Dataset Preprocessing/OPPORTUNITY/ACC-Position-Preprocessed/Trained Model/"
position = ["BACK","RUA","RLA","LUA","LLA"]
beta1=0.9
beta2=0.999

# %%
def onehot_to_label(y_onehot):
    a = np.argwhere(y_onehot == 1)
    return a[:, -1]

def A_plot():
    data = np.loadtxt('A_result.csv', delimiter=',')
    plt.figure()
    plt.plot(range(1, len(data[:, 0]) + 1), data[:, 0], color='blue', label='train')
    plt.plot(range(1, len(data[:, 1]) + 1), data[:, 1], color='red', label='test')
    plt.legend()
    plt.xlabel('Epoch', fontsize=14)
    plt.ylabel('Accuracy (%)', fontsize=14)
    plt.title('A Training and Test Accuracy', fontsize=20)
    
def B_plot():
    data = np.loadtxt('B_result.csv', delimiter=',')
    plt.figure()
    plt.plot(range(1, len(data[:, 0]) + 1), data[:, 0], color='blue', label='train')
    plt.plot(range(1, len(data[:, 1]) + 1), data[:, 1], color='red', label='test')
    plt.legend()
    plt.xlabel('Epoch', fontsize=14)
    plt.ylabel('Accuracy (%)', fontsize=14)
    plt.title('B Training and Test Accuracy', fontsize=20)
    
    
def plot_grad_flow(named_parameters):
    '''Plots the gradients flowing through different layers in the net during training.
    Can be used for checking for possible gradient vanishing / exploding problems.
    
    Usage: Plug this function in Trainer class after loss.backwards() as 
    "plot_grad_flow(self.model.named_parameters())" to visualize the gradient flow'''

    ave_grads = []
    max_grads= []
    layers = []
    for n, p in named_parameters:
        if(p.requires_grad) and ("bias" not in n):
            layers.append(n)
            ave_grads.append(p.grad.abs().mean())
            max_grads.append(p.grad.abs().max())
            
    plt.figure()
    plt.bar(np.arange(len(max_grads)), max_grads, alpha=0.5, lw=1, color="c")
    plt.bar(np.arange(len(max_grads)), ave_grads, alpha=0.5, lw=1, color="b")
    plt.hlines(0, 0, len(ave_grads)+1, lw=2, color="k" )
    plt.xticks(range(0,len(ave_grads), 1), layers, rotation="vertical")
    plt.xlim(left=0, right=len(ave_grads))
    plt.ylim(bottom = -0.001, top=0.02) # zoom in on the lower gradient regions
    plt.xlabel("Layers")
    plt.ylabel("average gradient")
    plt.title("Gradient flow")
    plt.grid(True)
    plt.legend([Line2D([0], [0], color="c", lw=4),
                Line2D([0], [0], color="b", lw=4),
                Line2D([0], [0], color="k", lw=4)], ['max-gradient', 'mean-gradient', 'zero-gradient'])

# %% [markdown]
# ### Data Structure

# %%
BACK_dataset_train = []
RUA_dataset_train = []
RLA_dataset_train = []
LUA_dataset_train = []
LLA_dataset_train = []
BACK_gt_train = []
RUA_gt_train = []
RLA_gt_train = []
LUA_gt_train = []
LLA_gt_train = []

# %%
BACK_dataset_valid = []
RUA_dataset_valid = []
RLA_dataset_valid = []
LUA_dataset_valid = []
LLA_dataset_valid = []
BACK_gt_valid = []
RUA_gt_valid = []
RLA_gt_valid = []
LUA_gt_valid = []
LLA_gt_valid = []

# %%
win_size=128
step_size=64
AXIS = 3
FROM = 0
TO = FROM+3
START = 3
END = 4

# %%
item = ["train","valid"]
user = ["user1","user2","user3","user4"]
position = ["back", "RUA", "RLA", "LUA","LLA"]

# %% [markdown]
# ### Load Data Files

# %%
for position_index in tqdm.tqdm(range(0,5)): #Back, RUA, RLA, LUA, LLA
    for split_index in range(0,2):
        file_name = user[selected_user-1] + "_" + position[position_index]+'_'+item[split_index]
        
        print(file_name)
        df = pd.read_csv(save_path+file_name+'.csv', sep=",")   
        len_df = df.shape[0]
        narray = df.to_numpy()

        for i in range(0, len_df, step_size):
            window = narray[i:i+win_size, FROM:TO]
            
            if window.shape[0] != win_size:
                continue
            else:
                reshaped_window = window.reshape(1,win_size,1,AXIS)
                gt = np.bincount(narray[i:i+win_size,START:END].astype(int).ravel()).argmax()
                
                if position_index == 0:
                    if split_index == 0:
                        BACK_dataset_train.append(reshaped_window)
                        BACK_gt_train.append(gt)
                    elif split_index == 1:
                        BACK_dataset_valid.append(reshaped_window)
                        BACK_gt_valid.append(gt)
                elif position_index == 1:
                    if split_index == 0:
                        RUA_dataset_train.append(reshaped_window)
                        RUA_gt_train.append(gt)
                    elif split_index == 1:
                        RUA_dataset_valid.append(reshaped_window)
                        RUA_gt_valid.append(gt)
                elif position_index == 2:
                    if split_index == 0:
                        RLA_dataset_train.append(reshaped_window)
                        RLA_gt_train.append(gt)
                    elif split_index == 1:
                        RLA_dataset_valid.append(reshaped_window)
                        RLA_gt_valid.append(gt)
                elif position_index == 3:
                    if split_index == 0:
                        LUA_dataset_train.append(reshaped_window)
                        LUA_gt_train.append(gt)
                    elif split_index == 1:
                        LUA_dataset_valid.append(reshaped_window)
                        LUA_gt_valid.append(gt)
                elif position_index == 4:
                    if split_index == 0:
                        LLA_dataset_train.append(reshaped_window)
                        LLA_gt_train.append(gt)
                    elif split_index == 1:
                        LLA_dataset_valid.append(reshaped_window)
                        LLA_gt_valid.append(gt)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# user4_back_train
#  40%|████      | 2/5 [00:00<00:00,  3.74it/s]
# user4_back_valid
# user4_RUA_train
# user4_RUA_valid
# user4_RLA_train
#  80%|████████  | 4/5 [00:00<00:00,  5.14it/s]
# user4_RLA_valid
# user4_LUA_train
# user4_LUA_valid
# user4_LLA_train
# 100%|██████████| 5/5 [00:00<00:00,  5.79it/s]
# user4_LLA_valid

# %%
len(BACK_gt_train)
# Out:
# 1312

# %%
np.unique(BACK_gt_train)
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# ## Source 1 PCA Visualization

# %%
pca_array = np.concatenate( RUA_dataset_train, axis=0 )
pca_array.shape
# Out:
# (1312, 128, 1, 3)

# %%
pca_array.shape[3]
# Out:
# 3

# %%
pca_array = np.reshape(pca_array, (pca_array.shape[0],(pca_array.shape[1]*pca_array.shape[2]*pca_array.shape[3])))
pca_array.shape
# Out:
# (1312, 384)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(pca_array)
principalDf = pd.DataFrame(data = principalComponents, columns = ['PC 1', 'PC 2'])

# %%
from sklearn.decomposition import PCA
pca3 = PCA(n_components=3)
principalComponents3 = pca3.fit_transform(pca_array)
principalDf3 = pd.DataFrame(data = principalComponents3, columns = ['PC 1', 'PC 2', 'PC 3'])

# %%
RUA_gt = np.array(RUA_gt_train)
RUA_gt_Df = pd.DataFrame(data = RUA_gt, columns = ['gt'])
final_pca_df = pd.concat([principalDf, RUA_gt_Df], axis = 1)
final_pca_df3 = pd.concat([principalDf3, RUA_gt_Df], axis = 1)

# %%
list(final_pca_df)
# Out:
# ['PC 1', 'PC 2', 'gt']

# %%
np.unique(RUA_gt_train)
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# #### PCA 2 Components

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('PC 1', fontsize = 15)
ax.set_ylabel('PC 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = [0,1,2,3]
target_label = ['Sitting','Standing','Lying','Walking']
colors = ['r', 'g', 'b', 'y']

for target, color in zip(targets,colors):
    indicesToKeep = final_pca_df['gt'] == target
    ax.scatter(final_pca_df.loc[indicesToKeep, 'PC 1']
               , final_pca_df.loc[indicesToKeep, 'PC 2']
               , c = color
               , s = 50)
ax.legend(target_label)
ax.grid()

# %% [markdown]
# #### 3 Components PCA

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(111, projection='3d') 
ax.set_xlabel('PC 1', fontsize = 15)
ax.set_ylabel('PC 2', fontsize = 15)
ax.set_zlabel('PC 3', fontsize = 15)
ax.set_title('3 component PCA', fontsize = 20)
targets = [0,1,2,3]
target_label = ['Sitting','Standing','Lying','Walking']
colors = ['r', 'g', 'b', 'y']

for target, color in zip(targets,colors):
    indicesToKeep = final_pca_df3['gt'] == target
    ax.scatter(final_pca_df3.loc[indicesToKeep, 'PC 1']
               , final_pca_df3.loc[indicesToKeep, 'PC 2']
               , final_pca_df3.loc[indicesToKeep, 'PC 3']
               , c = color
               , s = 50)
ax.legend(target_label)
ax.grid()

# %%
# gt_len = len(np.unique(S2_GT))

# %%
# gt_max_len = max(np.unique(S2_GT))

# %% [markdown]
# ## Source2 PCA Visualization

# %%
pca_array = np.concatenate( LUA_dataset_train, axis=0 )
pca_array.shape
# Out:
# (1312, 128, 1, 3)

# %%
pca_array.shape[3]
# Out:
# 3

# %%
pca_array = np.reshape(pca_array, (pca_array.shape[0],(pca_array.shape[1]*pca_array.shape[2]*pca_array.shape[3])))
pca_array.shape
# Out:
# (1312, 384)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(pca_array)
principalDf = pd.DataFrame(data = principalComponents, columns = ['PC 1', 'PC 2'])

# %%
from sklearn.decomposition import PCA
pca3 = PCA(n_components=3)
principalComponents3 = pca3.fit_transform(pca_array)
principalDf3 = pd.DataFrame(data = principalComponents3, columns = ['PC 1', 'PC 2', 'PC 3'])

# %%
LUA_gt = np.array(LUA_gt_train)
LUA_gt_Df = pd.DataFrame(data = LUA_gt, columns = ['gt'])
final_pca_df = pd.concat([principalDf, LUA_gt_Df], axis = 1)
final_pca_df3 = pd.concat([principalDf3, LUA_gt_Df], axis = 1)

# %%
list(final_pca_df)
# Out:
# ['PC 1', 'PC 2', 'gt']

# %%
np.unique(LUA_gt_train)
# Out:
# array([0, 1, 2, 3])

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('PC 1', fontsize = 15)
ax.set_ylabel('PC 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = [0,1,2,3]
target_label = ['Sitting','Standing','Lying','Walking']
colors = ['r', 'g', 'b', 'y']

for target, color in zip(targets,colors):
    indicesToKeep = final_pca_df['gt'] == target
    ax.scatter(final_pca_df.loc[indicesToKeep, 'PC 1']
               , final_pca_df.loc[indicesToKeep, 'PC 2']
               , c = color
               , s = 50)
ax.legend(target_label)
ax.grid()

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(111, projection='3d') 
ax.set_xlabel('PC 1', fontsize = 15)
ax.set_ylabel('PC 2', fontsize = 15)
ax.set_zlabel('PC 3', fontsize = 15)
ax.set_title('3 component PCA', fontsize = 20)
targets = [0,1,2,3]
target_label = ['Sitting','Standing','Lying','Walking']
colors = ['r', 'g', 'b', 'y']

for target, color in zip(targets,colors):
    indicesToKeep = final_pca_df3['gt'] == target
    ax.scatter(final_pca_df3.loc[indicesToKeep, 'PC 1']
               , final_pca_df3.loc[indicesToKeep, 'PC 2']
               , final_pca_df3.loc[indicesToKeep, 'PC 3']
               , c = color
               , s = 50)
ax.legend(target_label)
ax.grid()

# %% [markdown]
# # Target Data Visualization

# %%
pca_array = np.concatenate( BACK_dataset_train, axis=0 )
pca_array.shape
# Out:
# (1312, 128, 1, 3)

# %%
pca_array.shape[3]
# Out:
# 3

# %%
pca_array = np.reshape(pca_array, (pca_array.shape[0],(pca_array.shape[1]*pca_array.shape[2]*pca_array.shape[3])))
pca_array.shape
# Out:
# (1312, 384)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(pca_array)
principalDf = pd.DataFrame(data = principalComponents, columns = ['PC 1', 'PC 2'])

# %%
from sklearn.decomposition import PCA
pca3 = PCA(n_components=3)
principalComponents3 = pca3.fit_transform(pca_array)
principalDf3 = pd.DataFrame(data = principalComponents3, columns = ['PC 1', 'PC 2', 'PC 3'])

# %%
back_gt = np.array(BACK_gt_train)
back_gt_Df = pd.DataFrame(data = back_gt, columns = ['gt'])
final_pca_df = pd.concat([principalDf, back_gt_Df], axis = 1)
final_pca_df3 = pd.concat([principalDf3, back_gt_Df], axis = 1)

# %%
list(final_pca_df)
# Out:
# ['PC 1', 'PC 2', 'gt']

# %%
np.unique(BACK_gt_train)
# Out:
# array([0, 1, 2, 3])

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('PC 1', fontsize = 15)
ax.set_ylabel('PC 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = [0,1,2,3]
colors = ['r', 'g', 'b', 'y']
target_label = ['Sitting','Standing','Lying','Walking']

for target, color in zip(targets,colors):
    indicesToKeep = final_pca_df['gt'] == target
    ax.scatter(final_pca_df.loc[indicesToKeep, 'PC 1']
               , final_pca_df.loc[indicesToKeep, 'PC 2']
               , c = color
               , s = 50)
ax.legend(target_label)
ax.grid()

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(111, projection='3d') 
ax.set_xlabel('PC 1', fontsize = 15)
ax.set_ylabel('PC 2', fontsize = 15)
ax.set_zlabel('PC 3', fontsize = 15)
ax.set_title('3 component PCA', fontsize = 20)
targets = [0,1,2,3]
target_label = ['Sitting','Standing','Lying','Walking']
colors = ['r', 'g', 'b', 'y']

for target, color in zip(targets,colors):
    indicesToKeep = final_pca_df3['gt'] == target
    ax.scatter(final_pca_df3.loc[indicesToKeep, 'PC 1']
               , final_pca_df3.loc[indicesToKeep, 'PC 2']
               , final_pca_df3.loc[indicesToKeep, 'PC 3']
               , c = color
               , s = 50)
ax.legend(target_label)
ax.grid()

# %% [markdown]
# # Labelling starts from 0.

# %%
numpy_eye_max = max(np.unique(BACK_gt_train))+1

# %%
numpy_eye_max
# Out:
# 4

# %% [markdown]
# ### Source1 Data Processing

# %%
if source_one == 1:
    S1 = np.concatenate( BACK_dataset_train, axis=0 )
    S1_GT = np.array(BACK_gt_train  )
    S1_Test = np.concatenate( BACK_dataset_valid, axis=0 )
    S1_Test_GT = np.array(BACK_gt_valid  )
elif source_one == 2:
    S1 = np.concatenate( RUA_dataset_train, axis=0 )
    S1_GT = np.array(RUA_gt_train  )
    S1_Test = np.concatenate(RUA_dataset_valid, axis=0)
    S1_Test_GT = np.array(RUA_gt_valid)
elif source_one == 3:
    S1 = np.concatenate( RLA_dataset_train, axis=0 )
    S1_GT = np.array(RLA_gt_train  )
    S1_Test = np.concatenate( RLA_dataset_valid, axis=0 )
    S1_Test_GT = np.array(RLA_gt_valid  )
elif source_one == 4:
    S1 = np.concatenate( LUA_dataset_train, axis=0 )
    S1_GT = np.array(LUA_gt_train  )
    S1_Test = np.concatenate( LUA_dataset_valid, axis=0 )
    S1_Test_GT = np.array(LUA_gt_valid  )
elif source_one == 5:
    S1 = np.concatenate( LLA_dataset_train, axis=0 )
    S1_GT = np.array(LLA_gt_train  )
    S1_Test = np.concatenate( LLA_dataset_valid, axis=0 )
    S1_Test_GT = np.array(LLA_gt_valid  )

# %%
S1.shape
# Out:
# (1312, 128, 1, 3)

# %% [markdown]
# ### Source2 Data Processing

# %%
if source_two == 1:
    S2 = np.concatenate( BACK_dataset_train, axis=0 )
    S2_GT = np.array(BACK_gt_train  )
    S2_Test = np.concatenate( BACK_dataset_valid, axis=0 )
    S2_Test_GT = np.array(BACK_gt_valid  )
elif source_two == 2:
    S2 = np.concatenate( RUA_dataset_train, axis=0 )
    S2_GT = np.array(RUA_gt_train  )
    S2_Test = np.concatenate(RUA_dataset_valid, axis=0)
    S2_Test_GT = np.array(RUA_gt_valid)
elif source_two == 3:
    S2 = np.concatenate( RLA_dataset_train, axis=0 )
    S2_GT = np.array(RLA_gt_train  )
    S2_Test = np.concatenate( RLA_dataset_valid, axis=0 )
    S2_Test_GT = np.array(RLA_gt_valid  )
elif source_two == 4:
    S2 = np.concatenate( LUA_dataset_train, axis=0 )
    S2_GT = np.array(LUA_gt_train  )
    S2_Test = np.concatenate( LUA_dataset_valid, axis=0 )
    S2_Test_GT = np.array(LUA_gt_valid  )
elif source_two == 5:
    S2 = np.concatenate( LLA_dataset_train, axis=0 )
    S2_GT = np.array(LLA_gt_train  )
    S2_Test = np.concatenate( LLA_dataset_valid, axis=0 )
    S2_Test_GT = np.array(LLA_gt_valid  )

# %% [markdown]
# ### Target Data Processing

# %%
if selected_Target == 1:
    Target = np.concatenate( BACK_dataset_train, axis=0 )
    Target_GT = np.array(BACK_gt_train  )
elif selected_Target == 2:
    Target = np.concatenate(RUA_dataset_train, axis=0)
    Target_GT = np.array(RUA_gt_train)
elif selected_Target == 3:
    Target = np.concatenate( RLA_dataset_train, axis=0 )
    Target_GT = np.array(RLA_gt_train  )
elif selected_Target == 4:
    Target = np.concatenate( LUA_dataset_train, axis=0 )
    Target_GT = np.array(LUA_gt_train  )
elif selected_Target == 5:
    Target = np.concatenate( LLA_dataset_train, axis=0 )
    Target_GT = np.array(LLA_gt_train  )

# %%
output_gt_number = len(np.unique(S1_GT))
output_gt_number
# Out:
# 4

# %%
S1_GT = onehot_to_label(np.eye(numpy_eye_max)[S1_GT])
S1_Test_GT = onehot_to_label(np.eye(numpy_eye_max)[S1_Test_GT])
S1 =S1.astype(np.float32)
S1_GT =S1_GT.astype(np.float32)
S1_Test =S1_Test.astype(np.float32)
S1_Test_GT =S1_Test_GT.astype(np.float32)

# %%
S2_GT = onehot_to_label(np.eye(numpy_eye_max)[S2_GT])
S2_Test_GT = onehot_to_label(np.eye(numpy_eye_max)[S2_Test_GT])
S2 =S2.astype(np.float32)
S2_GT =S2_GT.astype(np.float32)
S2_Test =S2_Test.astype(np.float32)
S2_Test_GT =S2_Test_GT.astype(np.float32)

# %%
Target =Target.astype(np.float32)
Target_GT = onehot_to_label(np.eye(numpy_eye_max)[Target_GT])
Target_GT =Target_GT.astype(np.float32)

# %%
np.unique(Target_GT)
# Out:
# array([0., 1., 2., 3.], dtype=float32)

# %% [markdown]
# ### Data loader Class

# %%
class data_loader(Dataset):
    def __init__(self, samples, labels, transform=None):
        self.samples = samples
        self.labels = labels
        self.transform = transform

    def __getitem__(self, index):
        return self.samples[index], self.labels[index]

    def __len__(self):
        return len(self.samples)

# %%
def load(train_x, train_y, test_x, test_y, batch_size=64):
  
    train_x_swap = np.swapaxes(train_x,1,3)
    test_x_swap = np.swapaxes(test_x,1,3)

    train_set = data_loader(train_x_swap, train_y)
    test_set = data_loader(test_x_swap, test_y)
    
    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, drop_last=True)
    test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=True)
    return train_loader, test_loader

# %%
def test_load(test_x, test_y, batch_size=64):

    test_x_swap = np.swapaxes(test_x,1,3)
    test_set = data_loader(test_x_swap, test_y)
    test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)
    return test_loader

# %% [markdown]
# ### Model Saving Path

# %%
feature_save_path = pth_path+ "extractor.pth"
classifier_A_save_path = pth_path + "classifierA.pth"
classifier_B_save_path = pth_path + "classifierB.pth"

# %% [markdown]
# ### Train Model

# %%
BATCH_SIZE = 64
N_EPOCH = 250
LEARNING_RATE = 0.0002
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
A_result = []
B_result = []


def train(extractor, classifier_A, classifier_B, optimizer, S1_train, S1_test, S2_train, S2_test):
    n_batch = len(S1_train.dataset) // BATCH_SIZE
    criterion = nn.CrossEntropyLoss()

    for e in range(N_EPOCH):
        
        extractor.train()
        classifier_A.train()
        classifier_B.train()
        
        B_train_itr, B_test_itr = iter(S2_train), iter(S2_test)
        
        A_correct, B_correct = 0, 0
        A_total, B_total = 0, 0
        total_loss = 0
        
        
        for index, (A_sample, A_target) in enumerate(S1_train):
            
            try:
                B_sample, B_target = B_train_itr.next()
            except StopIteration:
                B_train_itr = iter(S2_train)
                B_sample, B_target = B_train_itr.next()

            
            A_sample, A_target = A_sample.to(DEVICE).float(), A_target.to(DEVICE).long()        
            A_sample = A_sample.view(-1, AXIS, 1, win_size)
            
            B_sample, B_target = B_sample.to(DEVICE).float(), B_target.to(DEVICE).long()        
            B_sample = B_sample.view(-1, AXIS, 1, win_size)
            
            
            A_feature = extractor(A_sample)
            A_output = classifier_A(A_feature)
            
            B_feature = extractor(B_sample)
            B_output = classifier_B(B_feature)
            
            A_loss = criterion(A_output, A_target)
            B_loss = criterion(B_output, B_target)


            total_loss = sum([A_loss, B_loss])
            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()
            
            total_loss += total_loss.item()
            
            _, A_predicted = torch.max(A_output.data, 1)
            A_total += A_target.size(0)
            A_correct += (A_predicted == A_target).sum()
            
            _, B_predicted = torch.max(B_output.data, 1)
            B_total += B_target.size(0)
            B_correct += (B_predicted == B_target).sum()

            if index % 20 == 0:
                tqdm.tqdm.write('Epoch: [{}/{}], Batch: [{}/{}], A_loss:{:.4f}, B_loss:{:.4f}'.format(e + 1,
                            N_EPOCH, index + 1, n_batch,A_loss.item(), B_loss.item()))
        
        A_acc_train = float(A_correct) * 100/ A_total
        B_acc_train = float(B_correct) * 100/ B_total

        tqdm.tqdm.write('Epoch: [{}/{}], A acc: {:.2f}%, B acc: {:.2f}%'.format(e + 1, N_EPOCH, A_acc_train, B_acc_train))

        # Testing
        extractor.eval()
        classifier_A.eval()
        classifier_B.eval()
        
        with torch.no_grad():
            A_correct, B_correct = 0, 0
            A_total, B_total = 0, 0
            correct, total = 0, 0
            
            for A_sample, A_target in S1_test:
                try:
                    B_sample, B_target = B_test_itr.next()
                except StopIteration:
                    B_test_itr = iter(S2_test)
                    B_sample, B_target = B_test_itr.next()

                
                A_sample, A_target = A_sample.to(DEVICE).float(), A_target.to(DEVICE).long()
                A_sample = A_sample.view(-1, AXIS, 1, win_size)
                
                B_sample, B_target = B_sample.to(DEVICE).float(), B_target.to(DEVICE).long()
                B_sample = B_sample.view(-1, AXIS, 1, win_size)
                
                
                feature = extractor(A_sample)
                A_output = classifier_A(feature)
                
                feature = extractor(B_sample)
                B_output = classifier_B(feature)
                
                _, A_predicted = torch.max(A_output.data, 1)
                A_total += A_target.size(0)
                A_correct += (A_predicted == A_target).sum()
                
                _, B_predicted = torch.max(B_output.data, 1)
                B_total += B_target.size(0)
                B_correct += (B_predicted == B_target).sum()
    
        
        A_acc_test = float(A_correct) * 100/ A_total
        B_acc_test = float(B_correct) * 100/ B_total
        tqdm.tqdm.write('Epoch: [{}/{}], A Valid Acc: {:.2f}%, B Valid Acc: {:.2f}%'.format(e + 1, N_EPOCH, A_acc_test, B_acc_test))
        
        A_result.append([A_acc_train, A_acc_test])
        B_result.append([B_acc_train, B_acc_test])
        
        A_result_np = np.array(A_result, dtype=float)
        B_result_np = np.array(B_result, dtype=float)
        
        np.savetxt('A_result.csv', A_result_np, fmt='%.2f', delimiter=',')
        np.savetxt('B_result.csv', B_result_np, fmt='%.2f', delimiter=',')
        
        torch.save(extractor.state_dict(),feature_save_path)
        torch.save(classifier_A.state_dict(),classifier_A_save_path)
        torch.save(classifier_B.state_dict(),classifier_B_save_path)

# %% [markdown]
# ### Execute the model

# %%
if __name__ == '__main__':
    torch.manual_seed(10)
    
    S1_train, S1_test = load(S1, S1_GT, S1_Test, S1_Test_GT)
    S2_train, S2_test = load(S2, S2_GT, S2_Test, S2_Test_GT)

    
    extractor = AccExtractor().to(DEVICE)
    classifier_A = AccClassifier(output_gt_number).to(DEVICE)
    classifier_B = AccClassifier(output_gt_number).to(DEVICE)
    
    param_list = list(extractor.parameters()) + list(classifier_A.parameters()) + list(classifier_B.parameters())
    optimizer = optim.Adam(params=param_list, lr=LEARNING_RATE, betas=(beta1, beta2))
    train(extractor, classifier_A, classifier_B, optimizer, S1_train, S1_test, S2_train, S2_test)
    
    A_plot()
    B_plot()
# Out:
# Epoch: [1/250], Batch: [1/20], A_loss:1.3819, B_loss:1.3774
# Epoch: [1/250], A acc: 46.48%, B acc: 47.73%
# Epoch: [1/250], A Valid Acc: 48.62%, B Valid Acc: 48.62%
# Epoch: [2/250], Batch: [1/20], A_loss:1.2181, B_loss:1.1256
# Epoch: [2/250], A acc: 48.12%, B acc: 48.98%
# Epoch: [2/250], A Valid Acc: 48.62%, B Valid Acc: 53.21%
# Epoch: [3/250], Batch: [1/20], A_loss:1.0252, B_loss:0.9767
# Epoch: [3/250], A acc: 49.53%, B acc: 60.86%
# Epoch: [3/250], A Valid Acc: 49.85%, B Valid Acc: 69.11%
# Epoch: [4/250], Batch: [1/20], A_loss:0.9669, B_loss:0.6986
# Epoch: [4/250], A acc: 56.41%, B acc: 67.97%
# Epoch: [4/250], A Valid Acc: 53.52%, B Valid Acc: 70.03%
# Epoch: [5/250], Batch: [1/20], A_loss:0.8526, B_loss:0.6160
# Epoch: [5/250], A acc: 60.16%, B acc: 66.33%
# Epoch: [5/250], A Valid Acc: 52.91%, B Valid Acc: 69.42%
# Epoch: [6/250], Batch: [1/20], A_loss:0.7354, B_loss:0.6558
# Epoch: [6/250], A acc: 62.27%, B acc: 68.12%
# Epoch: [6/250], A Valid Acc: 60.86%, B Valid Acc: 69.72%
# Epoch: [7/250], Batch: [1/20], A_loss:0.7617, B_loss:0.5482
# Epoch: [7/250], A acc: 64.14%, B acc: 69.06%
# Epoch: [7/250], A Valid Acc: 54.74%, B Valid Acc: 69.72%
# Epoch: [8/250], Batch: [1/20], A_loss:0.6373, B_loss:0.6674
# Epoch: [8/250], A acc: 64.06%, B acc: 67.89%
# Epoch: [8/250], A Valid Acc: 59.02%, B Valid Acc: 70.03%
# Epoch: [9/250], Batch: [1/20], A_loss:0.6762, B_loss:0.5480
# Epoch: [9/250], A acc: 66.95%, B acc: 67.50%
# Epoch: [9/250], A Valid Acc: 59.33%, B Valid Acc: 70.03%
# Epoch: [10/250], Batch: [1/20], A_loss:0.6087, B_loss:0.6771
# Epoch: [10/250], A acc: 66.56%, B acc: 69.61%
# Epoch: [10/250], A Valid Acc: 68.81%, B Valid Acc: 70.34%
# Epoch: [11/250], Batch: [1/20], A_loss:0.6309, B_loss:0.6006
# Epoch: [11/250], A acc: 65.31%, B acc: 70.23%
# Epoch: [11/250], A Valid Acc: 60.24%, B Valid Acc: 70.34%
# Epoch: [12/250], Batch: [1/20], A_loss:0.6283, B_loss:0.5070
# Epoch: [12/250], A acc: 67.73%, B acc: 71.02%
# Epoch: [12/250], A Valid Acc: 60.24%, B Valid Acc: 71.25%
# Epoch: [13/250], Batch: [1/20], A_loss:0.6057, B_loss:0.4710
# Epoch: [13/250], A acc: 68.59%, B acc: 70.78%
# Epoch: [13/250], A Valid Acc: 67.58%, B Valid Acc: 77.68%
# Epoch: [14/250], Batch: [1/20], A_loss:0.5657, B_loss:0.4874
# Epoch: [14/250], A acc: 66.72%, B acc: 72.19%
# Epoch: [14/250], A Valid Acc: 68.20%, B Valid Acc: 70.34%
# Epoch: [15/250], Batch: [1/20], A_loss:0.6157, B_loss:0.5929
# Epoch: [15/250], A acc: 69.69%, B acc: 72.89%
# Epoch: [15/250], A Valid Acc: 70.95%, B Valid Acc: 79.51%
# Epoch: [16/250], Batch: [1/20], A_loss:0.5920, B_loss:0.4471
# Epoch: [16/250], A acc: 70.16%, B acc: 75.31%
# Epoch: [16/250], A Valid Acc: 69.42%, B Valid Acc: 79.20%
# Epoch: [17/250], Batch: [1/20], A_loss:0.7039, B_loss:0.4881
# Epoch: [17/250], A acc: 69.22%, B acc: 74.45%
# Epoch: [17/250], A Valid Acc: 74.01%, B Valid Acc: 77.68%
# Epoch: [18/250], Batch: [1/20], A_loss:0.5514, B_loss:0.5765
# Epoch: [18/250], A acc: 68.05%, B acc: 74.45%
# Epoch: [18/250], A Valid Acc: 73.39%, B Valid Acc: 78.90%
# Epoch: [19/250], Batch: [1/20], A_loss:0.5584, B_loss:0.4092
# Epoch: [19/250], A acc: 71.56%, B acc: 76.02%
# Epoch: [19/250], A Valid Acc: 74.31%, B Valid Acc: 76.76%
# Epoch: [20/250], Batch: [1/20], A_loss:0.5103, B_loss:0.4421
# Epoch: [20/250], A acc: 69.22%, B acc: 77.66%
# Epoch: [20/250], A Valid Acc: 67.28%, B Valid Acc: 80.12%
# Epoch: [21/250], Batch: [1/20], A_loss:0.6800, B_loss:0.4268
# Epoch: [21/250], A acc: 70.23%, B acc: 76.56%
# Epoch: [21/250], A Valid Acc: 72.48%, B Valid Acc: 78.29%
# Epoch: [22/250], Batch: [1/20], A_loss:0.4909, B_loss:0.3488
# Epoch: [22/250], A acc: 71.25%, B acc: 77.97%
# Epoch: [22/250], A Valid Acc: 74.31%, B Valid Acc: 80.73%
# Epoch: [23/250], Batch: [1/20], A_loss:0.4732, B_loss:0.5190
# Epoch: [23/250], A acc: 71.80%, B acc: 79.30%
# Epoch: [23/250], A Valid Acc: 75.84%, B Valid Acc: 82.87%
# Epoch: [24/250], Batch: [1/20], A_loss:0.5314, B_loss:0.4179
# Epoch: [24/250], A acc: 70.78%, B acc: 82.11%
# Epoch: [24/250], A Valid Acc: 75.84%, B Valid Acc: 84.10%
# Epoch: [25/250], Batch: [1/20], A_loss:0.5483, B_loss:0.5058
# Epoch: [25/250], A acc: 73.52%, B acc: 81.02%
# Epoch: [25/250], A Valid Acc: 73.70%, B Valid Acc: 83.79%
# Epoch: [26/250], Batch: [1/20], A_loss:0.5417, B_loss:0.5258
# Epoch: [26/250], A acc: 73.20%, B acc: 81.09%
# Epoch: [26/250], A Valid Acc: 75.54%, B Valid Acc: 77.98%
# Epoch: [27/250], Batch: [1/20], A_loss:0.4810, B_loss:0.4251
# Epoch: [27/250], A acc: 72.81%, B acc: 83.36%
# Epoch: [27/250], A Valid Acc: 75.54%, B Valid Acc: 84.40%
# Epoch: [28/250], Batch: [1/20], A_loss:0.4698, B_loss:0.4322
# Epoch: [28/250], A acc: 75.08%, B acc: 81.88%
# Epoch: [28/250], A Valid Acc: 75.23%, B Valid Acc: 77.37%
# Epoch: [29/250], Batch: [1/20], A_loss:0.5440, B_loss:0.3490
# Epoch: [29/250], A acc: 76.02%, B acc: 79.77%
# Epoch: [29/250], A Valid Acc: 78.29%, B Valid Acc: 84.10%
# Epoch: [30/250], Batch: [1/20], A_loss:0.5888, B_loss:0.3527
# Epoch: [30/250], A acc: 76.02%, B acc: 81.88%
# Epoch: [30/250], A Valid Acc: 79.20%, B Valid Acc: 86.24%
# Epoch: [31/250], Batch: [1/20], A_loss:0.5403, B_loss:0.4227
# Epoch: [31/250], A acc: 77.11%, B acc: 85.39%
# Epoch: [31/250], A Valid Acc: 76.15%, B Valid Acc: 86.24%
# Epoch: [32/250], Batch: [1/20], A_loss:0.5407, B_loss:0.3188
# Epoch: [32/250], A acc: 77.58%, B acc: 87.34%
# Epoch: [32/250], A Valid Acc: 79.82%, B Valid Acc: 86.85%
# Epoch: [33/250], Batch: [1/20], A_loss:0.5813, B_loss:0.3715
# Epoch: [33/250], A acc: 75.86%, B acc: 84.69%
# Epoch: [33/250], A Valid Acc: 73.39%, B Valid Acc: 82.57%
# Epoch: [34/250], Batch: [1/20], A_loss:0.4878, B_loss:0.5447
# Epoch: [34/250], A acc: 75.86%, B acc: 84.14%
# Epoch: [34/250], A Valid Acc: 75.84%, B Valid Acc: 87.46%
# Epoch: [35/250], Batch: [1/20], A_loss:0.4738, B_loss:0.2317
# Epoch: [35/250], A acc: 78.44%, B acc: 86.48%
# Epoch: [35/250], A Valid Acc: 80.12%, B Valid Acc: 86.54%
# Epoch: [36/250], Batch: [1/20], A_loss:0.4419, B_loss:0.4929
# Epoch: [36/250], A acc: 79.30%, B acc: 88.20%
# Epoch: [36/250], A Valid Acc: 79.82%, B Valid Acc: 87.46%
# Epoch: [37/250], Batch: [1/20], A_loss:0.6606, B_loss:0.2599
# Epoch: [37/250], A acc: 76.17%, B acc: 87.42%
# Epoch: [37/250], A Valid Acc: 81.04%, B Valid Acc: 87.77%
# Epoch: [38/250], Batch: [1/20], A_loss:0.4192, B_loss:0.3393
# Epoch: [38/250], A acc: 79.06%, B acc: 87.34%
# Epoch: [38/250], A Valid Acc: 80.12%, B Valid Acc: 88.69%
# Epoch: [39/250], Batch: [1/20], A_loss:0.3928, B_loss:0.2887
# Epoch: [39/250], A acc: 79.92%, B acc: 86.72%
# Epoch: [39/250], A Valid Acc: 82.26%, B Valid Acc: 88.07%
# Epoch: [40/250], Batch: [1/20], A_loss:0.3828, B_loss:0.3428
# Epoch: [40/250], A acc: 79.38%, B acc: 87.19%
# Epoch: [40/250], A Valid Acc: 81.96%, B Valid Acc: 89.30%
# Epoch: [41/250], Batch: [1/20], A_loss:0.3943, B_loss:0.4255
# Epoch: [41/250], A acc: 80.16%, B acc: 87.34%
# Epoch: [41/250], A Valid Acc: 81.96%, B Valid Acc: 89.30%
# Epoch: [42/250], Batch: [1/20], A_loss:0.4456, B_loss:0.3267
# Epoch: [42/250], A acc: 81.17%, B acc: 88.52%
# Epoch: [42/250], A Valid Acc: 78.59%, B Valid Acc: 89.60%
# Epoch: [43/250], Batch: [1/20], A_loss:0.4697, B_loss:0.2238
# Epoch: [43/250], A acc: 79.92%, B acc: 90.16%
# Epoch: [43/250], A Valid Acc: 84.40%, B Valid Acc: 88.99%
# Epoch: [44/250], Batch: [1/20], A_loss:0.4433, B_loss:0.4295
# Epoch: [44/250], A acc: 80.70%, B acc: 89.22%
# Epoch: [44/250], A Valid Acc: 82.87%, B Valid Acc: 90.83%
# Epoch: [45/250], Batch: [1/20], A_loss:0.3387, B_loss:0.4014
# Epoch: [45/250], A acc: 82.03%, B acc: 89.53%
# Epoch: [45/250], A Valid Acc: 83.18%, B Valid Acc: 90.52%
# Epoch: [46/250], Batch: [1/20], A_loss:0.5362, B_loss:0.3414
# Epoch: [46/250], A acc: 83.12%, B acc: 90.62%
# Epoch: [46/250], A Valid Acc: 84.71%, B Valid Acc: 90.83%
# Epoch: [47/250], Batch: [1/20], A_loss:0.3253, B_loss:0.4522
# Epoch: [47/250], A acc: 83.75%, B acc: 90.16%
# Epoch: [47/250], A Valid Acc: 83.79%, B Valid Acc: 90.52%
# Epoch: [48/250], Batch: [1/20], A_loss:0.3847, B_loss:0.3630
# Epoch: [48/250], A acc: 82.03%, B acc: 90.39%
# Epoch: [48/250], A Valid Acc: 75.54%, B Valid Acc: 89.91%
# Epoch: [49/250], Batch: [1/20], A_loss:0.5137, B_loss:0.2537
# Epoch: [49/250], A acc: 81.72%, B acc: 90.31%
# Epoch: [49/250], A Valid Acc: 82.26%, B Valid Acc: 90.21%
# Epoch: [50/250], Batch: [1/20], A_loss:0.4337, B_loss:0.3005
# Epoch: [50/250], A acc: 83.59%, B acc: 88.67%
# Epoch: [50/250], A Valid Acc: 85.93%, B Valid Acc: 88.07%
# Epoch: [51/250], Batch: [1/20], A_loss:0.4707, B_loss:0.3247
# Epoch: [51/250], A acc: 83.20%, B acc: 90.86%
# Epoch: [51/250], A Valid Acc: 85.02%, B Valid Acc: 92.35%
# Epoch: [52/250], Batch: [1/20], A_loss:0.4806, B_loss:0.3998
# Epoch: [52/250], A acc: 83.83%, B acc: 90.62%
# Epoch: [52/250], A Valid Acc: 84.40%, B Valid Acc: 91.13%
# Epoch: [53/250], Batch: [1/20], A_loss:0.4131, B_loss:0.4350
# Epoch: [53/250], A acc: 83.44%, B acc: 89.61%
# Epoch: [53/250], A Valid Acc: 83.49%, B Valid Acc: 90.21%
# Epoch: [54/250], Batch: [1/20], A_loss:0.3686, B_loss:0.2816
# Epoch: [54/250], A acc: 85.78%, B acc: 90.39%
# Epoch: [54/250], A Valid Acc: 86.24%, B Valid Acc: 89.91%
# Epoch: [55/250], Batch: [1/20], A_loss:0.4768, B_loss:0.2626
# Epoch: [55/250], A acc: 85.70%, B acc: 90.47%
# Epoch: [55/250], A Valid Acc: 84.40%, B Valid Acc: 89.91%
# Epoch: [56/250], Batch: [1/20], A_loss:0.3672, B_loss:0.2927
# Epoch: [56/250], A acc: 84.61%, B acc: 87.19%
# Epoch: [56/250], A Valid Acc: 82.87%, B Valid Acc: 88.38%
# Epoch: [57/250], Batch: [1/20], A_loss:0.4111, B_loss:0.3773
# Epoch: [57/250], A acc: 84.22%, B acc: 90.00%
# Epoch: [57/250], A Valid Acc: 85.63%, B Valid Acc: 91.13%
# Epoch: [58/250], Batch: [1/20], A_loss:0.4199, B_loss:0.4687
# Epoch: [58/250], A acc: 86.02%, B acc: 90.08%
# Epoch: [58/250], A Valid Acc: 88.07%, B Valid Acc: 92.35%
# Epoch: [59/250], Batch: [1/20], A_loss:0.3393, B_loss:0.3059
# Epoch: [59/250], A acc: 86.02%, B acc: 91.17%
# Epoch: [59/250], A Valid Acc: 86.54%, B Valid Acc: 90.21%
# Epoch: [60/250], Batch: [1/20], A_loss:0.2861, B_loss:0.2431
# Epoch: [60/250], A acc: 85.70%, B acc: 90.31%
# Epoch: [60/250], A Valid Acc: 85.93%, B Valid Acc: 89.91%
# Epoch: [61/250], Batch: [1/20], A_loss:0.3911, B_loss:0.2387
# Epoch: [61/250], A acc: 86.25%, B acc: 90.78%
# Epoch: [61/250], A Valid Acc: 86.85%, B Valid Acc: 90.52%
# Epoch: [62/250], Batch: [1/20], A_loss:0.3791, B_loss:0.2380
# Epoch: [62/250], A acc: 86.17%, B acc: 91.09%
# Epoch: [62/250], A Valid Acc: 87.46%, B Valid Acc: 92.66%
# Epoch: [63/250], Batch: [1/20], A_loss:0.3585, B_loss:0.2253
# Epoch: [63/250], A acc: 86.64%, B acc: 90.86%
# Epoch: [63/250], A Valid Acc: 86.85%, B Valid Acc: 92.66%
# Epoch: [64/250], Batch: [1/20], A_loss:0.3345, B_loss:0.2632
# Epoch: [64/250], A acc: 86.09%, B acc: 89.92%
# Epoch: [64/250], A Valid Acc: 86.54%, B Valid Acc: 92.05%
# Epoch: [65/250], Batch: [1/20], A_loss:0.4129, B_loss:0.2758
# Epoch: [65/250], A acc: 86.48%, B acc: 90.16%
# Epoch: [65/250], A Valid Acc: 81.04%, B Valid Acc: 84.40%
# Epoch: [66/250], Batch: [1/20], A_loss:0.3227, B_loss:0.4365
# Epoch: [66/250], A acc: 86.02%, B acc: 89.53%
# Epoch: [66/250], A Valid Acc: 86.54%, B Valid Acc: 92.35%
# Epoch: [67/250], Batch: [1/20], A_loss:0.4332, B_loss:0.2694
# Epoch: [67/250], A acc: 86.25%, B acc: 91.17%
# Epoch: [67/250], A Valid Acc: 84.40%, B Valid Acc: 91.44%
# Epoch: [68/250], Batch: [1/20], A_loss:0.2818, B_loss:0.2078
# Epoch: [68/250], A acc: 87.42%, B acc: 90.70%
# Epoch: [68/250], A Valid Acc: 88.07%, B Valid Acc: 91.74%
# Epoch: [69/250], Batch: [1/20], A_loss:0.2987, B_loss:0.2756
# Epoch: [69/250], A acc: 88.67%, B acc: 90.94%
# Epoch: [69/250], A Valid Acc: 86.85%, B Valid Acc: 91.74%
# Epoch: [70/250], Batch: [1/20], A_loss:0.3931, B_loss:0.2408
# Epoch: [70/250], A acc: 87.11%, B acc: 89.77%
# Epoch: [70/250], A Valid Acc: 81.96%, B Valid Acc: 89.60%
# Epoch: [71/250], Batch: [1/20], A_loss:0.3067, B_loss:0.2891
# Epoch: [71/250], A acc: 87.27%, B acc: 90.94%
# Epoch: [71/250], A Valid Acc: 87.46%, B Valid Acc: 93.88%
# Epoch: [72/250], Batch: [1/20], A_loss:0.4351, B_loss:0.1427
# Epoch: [72/250], A acc: 87.42%, B acc: 91.17%
# Epoch: [72/250], A Valid Acc: 84.71%, B Valid Acc: 90.21%
# Epoch: [73/250], Batch: [1/20], A_loss:0.3893, B_loss:0.2161
# Epoch: [73/250], A acc: 86.41%, B acc: 91.41%
# Epoch: [73/250], A Valid Acc: 88.07%, B Valid Acc: 94.19%
# Epoch: [74/250], Batch: [1/20], A_loss:0.4170, B_loss:0.1440
# Epoch: [74/250], A acc: 89.06%, B acc: 90.94%
# Epoch: [74/250], A Valid Acc: 85.02%, B Valid Acc: 90.52%
# Epoch: [75/250], Batch: [1/20], A_loss:0.2699, B_loss:0.1945
# Epoch: [75/250], A acc: 89.22%, B acc: 91.56%
# Epoch: [75/250], A Valid Acc: 87.77%, B Valid Acc: 93.27%
# Epoch: [76/250], Batch: [1/20], A_loss:0.2813, B_loss:0.3378
# Epoch: [76/250], A acc: 88.98%, B acc: 92.11%
# Epoch: [76/250], A Valid Acc: 87.46%, B Valid Acc: 93.88%
# Epoch: [77/250], Batch: [1/20], A_loss:0.3206, B_loss:0.1748
# Epoch: [77/250], A acc: 88.12%, B acc: 92.42%
# Epoch: [77/250], A Valid Acc: 88.07%, B Valid Acc: 91.44%
# Epoch: [78/250], Batch: [1/20], A_loss:0.1748, B_loss:0.1976
# Epoch: [78/250], A acc: 88.28%, B acc: 91.64%
# Epoch: [78/250], A Valid Acc: 84.71%, B Valid Acc: 89.91%
# Epoch: [79/250], Batch: [1/20], A_loss:0.3329, B_loss:0.3463
# Epoch: [79/250], A acc: 89.92%, B acc: 91.80%
# Epoch: [79/250], A Valid Acc: 87.77%, B Valid Acc: 93.88%
# Epoch: [80/250], Batch: [1/20], A_loss:0.3042, B_loss:0.2716
# Epoch: [80/250], A acc: 88.59%, B acc: 90.31%
# Epoch: [80/250], A Valid Acc: 87.46%, B Valid Acc: 92.05%
# Epoch: [81/250], Batch: [1/20], A_loss:0.3508, B_loss:0.2880
# Epoch: [81/250], A acc: 89.30%, B acc: 91.56%
# Epoch: [81/250], A Valid Acc: 87.77%, B Valid Acc: 92.97%
# Epoch: [82/250], Batch: [1/20], A_loss:0.2218, B_loss:0.2671
# Epoch: [82/250], A acc: 90.00%, B acc: 91.17%
# Epoch: [82/250], A Valid Acc: 88.69%, B Valid Acc: 93.58%
# Epoch: [83/250], Batch: [1/20], A_loss:0.3108, B_loss:0.2118
# Epoch: [83/250], A acc: 89.38%, B acc: 92.34%
# Epoch: [83/250], A Valid Acc: 83.79%, B Valid Acc: 91.44%
# Epoch: [84/250], Batch: [1/20], A_loss:0.3560, B_loss:0.3514
# Epoch: [84/250], A acc: 89.06%, B acc: 91.72%
# Epoch: [84/250], A Valid Acc: 87.77%, B Valid Acc: 92.35%
# Epoch: [85/250], Batch: [1/20], A_loss:0.3066, B_loss:0.1281
# Epoch: [85/250], A acc: 89.61%, B acc: 92.42%
# Epoch: [85/250], A Valid Acc: 85.02%, B Valid Acc: 90.21%
# Epoch: [86/250], Batch: [1/20], A_loss:0.2102, B_loss:0.1630
# Epoch: [86/250], A acc: 89.22%, B acc: 91.95%
# Epoch: [86/250], A Valid Acc: 88.07%, B Valid Acc: 94.19%
# Epoch: [87/250], Batch: [1/20], A_loss:0.2189, B_loss:0.1499
# Epoch: [87/250], A acc: 88.83%, B acc: 91.80%
# Epoch: [87/250], A Valid Acc: 82.57%, B Valid Acc: 86.24%
# Epoch: [88/250], Batch: [1/20], A_loss:0.2569, B_loss:0.4440
# Epoch: [88/250], A acc: 89.77%, B acc: 91.56%
# Epoch: [88/250], A Valid Acc: 89.30%, B Valid Acc: 91.44%
# Epoch: [89/250], Batch: [1/20], A_loss:0.1847, B_loss:0.3184
# Epoch: [89/250], A acc: 90.70%, B acc: 91.02%
# Epoch: [89/250], A Valid Acc: 88.69%, B Valid Acc: 91.74%
# Epoch: [90/250], Batch: [1/20], A_loss:0.2064, B_loss:0.2975
# Epoch: [90/250], A acc: 90.55%, B acc: 91.80%
# Epoch: [90/250], A Valid Acc: 88.38%, B Valid Acc: 93.58%
# Epoch: [91/250], Batch: [1/20], A_loss:0.1951, B_loss:0.1654
# Epoch: [91/250], A acc: 90.39%, B acc: 91.95%
# Epoch: [91/250], A Valid Acc: 88.38%, B Valid Acc: 94.19%
# Epoch: [92/250], Batch: [1/20], A_loss:0.1907, B_loss:0.2808
# Epoch: [92/250], A acc: 90.78%, B acc: 91.64%
# Epoch: [92/250], A Valid Acc: 89.30%, B Valid Acc: 92.35%
# Epoch: [93/250], Batch: [1/20], A_loss:0.1912, B_loss:0.2611
# Epoch: [93/250], A acc: 91.33%, B acc: 93.05%
# Epoch: [93/250], A Valid Acc: 88.69%, B Valid Acc: 92.05%
# Epoch: [94/250], Batch: [1/20], A_loss:0.1920, B_loss:0.1927
# Epoch: [94/250], A acc: 90.78%, B acc: 92.27%
# Epoch: [94/250], A Valid Acc: 88.99%, B Valid Acc: 94.19%
# Epoch: [95/250], Batch: [1/20], A_loss:0.2967, B_loss:0.2992
# Epoch: [95/250], A acc: 90.31%, B acc: 92.58%
# Epoch: [95/250], A Valid Acc: 89.30%, B Valid Acc: 90.52%
# Epoch: [96/250], Batch: [1/20], A_loss:0.2179, B_loss:0.1263
# Epoch: [96/250], A acc: 89.53%, B acc: 92.03%
# Epoch: [96/250], A Valid Acc: 81.65%, B Valid Acc: 92.97%
# Epoch: [97/250], Batch: [1/20], A_loss:0.2508, B_loss:0.1773
# Epoch: [97/250], A acc: 90.70%, B acc: 92.27%
# Epoch: [97/250], A Valid Acc: 89.30%, B Valid Acc: 93.58%
# Epoch: [98/250], Batch: [1/20], A_loss:0.2477, B_loss:0.1989
# Epoch: [98/250], A acc: 91.33%, B acc: 92.81%
# Epoch: [98/250], A Valid Acc: 88.38%, B Valid Acc: 89.60%
# Epoch: [99/250], Batch: [1/20], A_loss:0.1964, B_loss:0.2381
# Epoch: [99/250], A acc: 90.00%, B acc: 92.50%
# Epoch: [99/250], A Valid Acc: 87.77%, B Valid Acc: 93.58%
# Epoch: [100/250], Batch: [1/20], A_loss:0.2800, B_loss:0.2545
# Epoch: [100/250], A acc: 91.41%, B acc: 92.89%
# Epoch: [100/250], A Valid Acc: 89.60%, B Valid Acc: 89.60%
# Epoch: [101/250], Batch: [1/20], A_loss:0.3549, B_loss:0.2831
# Epoch: [101/250], A acc: 90.23%, B acc: 92.42%
# Epoch: [101/250], A Valid Acc: 81.65%, B Valid Acc: 92.97%
# Epoch: [102/250], Batch: [1/20], A_loss:0.2979, B_loss:0.1316
# Epoch: [102/250], A acc: 89.69%, B acc: 90.70%
# Epoch: [102/250], A Valid Acc: 90.52%, B Valid Acc: 94.50%
# Epoch: [103/250], Batch: [1/20], A_loss:0.3079, B_loss:0.2446
# Epoch: [103/250], A acc: 90.08%, B acc: 92.66%
# Epoch: [103/250], A Valid Acc: 88.07%, B Valid Acc: 92.97%
# Epoch: [104/250], Batch: [1/20], A_loss:0.1786, B_loss:0.1297
# Epoch: [104/250], A acc: 91.25%, B acc: 92.66%
# Epoch: [104/250], A Valid Acc: 89.91%, B Valid Acc: 92.35%
# Epoch: [105/250], Batch: [1/20], A_loss:0.3201, B_loss:0.2285
# Epoch: [105/250], A acc: 90.70%, B acc: 92.03%
# Epoch: [105/250], A Valid Acc: 86.54%, B Valid Acc: 92.97%
# Epoch: [106/250], Batch: [1/20], A_loss:0.2680, B_loss:0.2356
# Epoch: [106/250], A acc: 90.78%, B acc: 92.27%
# Epoch: [106/250], A Valid Acc: 89.91%, B Valid Acc: 94.50%
# Epoch: [107/250], Batch: [1/20], A_loss:0.1916, B_loss:0.1301
# Epoch: [107/250], A acc: 91.02%, B acc: 92.58%
# Epoch: [107/250], A Valid Acc: 86.54%, B Valid Acc: 90.83%
# Epoch: [108/250], Batch: [1/20], A_loss:0.2106, B_loss:0.1194
# Epoch: [108/250], A acc: 91.09%, B acc: 92.97%
# Epoch: [108/250], A Valid Acc: 89.91%, B Valid Acc: 94.50%
# Epoch: [109/250], Batch: [1/20], A_loss:0.2940, B_loss:0.1333
# Epoch: [109/250], A acc: 91.64%, B acc: 92.11%
# Epoch: [109/250], A Valid Acc: 88.99%, B Valid Acc: 92.05%
# Epoch: [110/250], Batch: [1/20], A_loss:0.1958, B_loss:0.1356
# Epoch: [110/250], A acc: 92.42%, B acc: 92.34%
# Epoch: [110/250], A Valid Acc: 89.60%, B Valid Acc: 93.27%
# Epoch: [111/250], Batch: [1/20], A_loss:0.2610, B_loss:0.1598
# Epoch: [111/250], A acc: 92.03%, B acc: 92.58%
# Epoch: [111/250], A Valid Acc: 89.60%, B Valid Acc: 93.88%
# Epoch: [112/250], Batch: [1/20], A_loss:0.2181, B_loss:0.2308
# Epoch: [112/250], A acc: 92.50%, B acc: 93.20%
# Epoch: [112/250], A Valid Acc: 88.99%, B Valid Acc: 93.58%
# Epoch: [113/250], Batch: [1/20], A_loss:0.2038, B_loss:0.1621
# Epoch: [113/250], A acc: 91.80%, B acc: 93.20%
# Epoch: [113/250], A Valid Acc: 90.21%, B Valid Acc: 93.88%
# Epoch: [114/250], Batch: [1/20], A_loss:0.2464, B_loss:0.1506
# Epoch: [114/250], A acc: 91.25%, B acc: 93.83%
# Epoch: [114/250], A Valid Acc: 86.24%, B Valid Acc: 88.99%
# Epoch: [115/250], Batch: [1/20], A_loss:0.2213, B_loss:0.2453
# Epoch: [115/250], A acc: 92.11%, B acc: 92.66%
# Epoch: [115/250], A Valid Acc: 88.07%, B Valid Acc: 89.91%
# Epoch: [116/250], Batch: [1/20], A_loss:0.2567, B_loss:0.3623
# Epoch: [116/250], A acc: 90.94%, B acc: 93.12%
# Epoch: [116/250], A Valid Acc: 88.99%, B Valid Acc: 91.44%
# Epoch: [117/250], Batch: [1/20], A_loss:0.1540, B_loss:0.1651
# Epoch: [117/250], A acc: 92.42%, B acc: 93.36%
# Epoch: [117/250], A Valid Acc: 89.30%, B Valid Acc: 90.21%
# Epoch: [118/250], Batch: [1/20], A_loss:0.2621, B_loss:0.2257
# Epoch: [118/250], A acc: 92.73%, B acc: 92.66%
# Epoch: [118/250], A Valid Acc: 89.91%, B Valid Acc: 92.66%
# Epoch: [119/250], Batch: [1/20], A_loss:0.2398, B_loss:0.0991
# Epoch: [119/250], A acc: 92.11%, B acc: 91.64%
# Epoch: [119/250], A Valid Acc: 85.93%, B Valid Acc: 93.27%
# Epoch: [120/250], Batch: [1/20], A_loss:0.3464, B_loss:0.2427
# Epoch: [120/250], A acc: 89.45%, B acc: 92.58%
# Epoch: [120/250], A Valid Acc: 83.79%, B Valid Acc: 88.07%
# Epoch: [121/250], Batch: [1/20], A_loss:0.2031, B_loss:0.2900
# Epoch: [121/250], A acc: 90.78%, B acc: 92.58%
# Epoch: [121/250], A Valid Acc: 86.85%, B Valid Acc: 92.35%
# Epoch: [122/250], Batch: [1/20], A_loss:0.2058, B_loss:0.2529
# Epoch: [122/250], A acc: 91.17%, B acc: 92.66%
# Epoch: [122/250], A Valid Acc: 87.16%, B Valid Acc: 94.50%
# Epoch: [123/250], Batch: [1/20], A_loss:0.2551, B_loss:0.2359
# Epoch: [123/250], A acc: 92.19%, B acc: 93.28%
# Epoch: [123/250], A Valid Acc: 87.77%, B Valid Acc: 92.05%
# Epoch: [124/250], Batch: [1/20], A_loss:0.1955, B_loss:0.1151
# Epoch: [124/250], A acc: 93.83%, B acc: 93.28%
# Epoch: [124/250], A Valid Acc: 88.99%, B Valid Acc: 95.41%
# Epoch: [125/250], Batch: [1/20], A_loss:0.2156, B_loss:0.1372
# Epoch: [125/250], A acc: 93.12%, B acc: 92.89%
# Epoch: [125/250], A Valid Acc: 89.60%, B Valid Acc: 94.19%
# Epoch: [126/250], Batch: [1/20], A_loss:0.2194, B_loss:0.0962
# Epoch: [126/250], A acc: 93.05%, B acc: 93.59%
# Epoch: [126/250], A Valid Acc: 91.13%, B Valid Acc: 92.05%
# Epoch: [127/250], Batch: [1/20], A_loss:0.1096, B_loss:0.0843
# Epoch: [127/250], A acc: 92.11%, B acc: 93.12%
# Epoch: [127/250], A Valid Acc: 88.38%, B Valid Acc: 93.27%
# Epoch: [128/250], Batch: [1/20], A_loss:0.2604, B_loss:0.2696
# Epoch: [128/250], A acc: 92.50%, B acc: 92.81%
# Epoch: [128/250], A Valid Acc: 87.16%, B Valid Acc: 92.35%
# Epoch: [129/250], Batch: [1/20], A_loss:0.2771, B_loss:0.1858
# Epoch: [129/250], A acc: 93.20%, B acc: 93.36%
# Epoch: [129/250], A Valid Acc: 88.99%, B Valid Acc: 95.11%
# Epoch: [130/250], Batch: [1/20], A_loss:0.2207, B_loss:0.1666
# Epoch: [130/250], A acc: 92.27%, B acc: 93.44%
# Epoch: [130/250], A Valid Acc: 87.16%, B Valid Acc: 91.13%
# Epoch: [131/250], Batch: [1/20], A_loss:0.2712, B_loss:0.1758
# Epoch: [131/250], A acc: 92.19%, B acc: 92.81%
# Epoch: [131/250], A Valid Acc: 89.91%, B Valid Acc: 95.11%
# Epoch: [132/250], Batch: [1/20], A_loss:0.1391, B_loss:0.0932
# Epoch: [132/250], A acc: 92.97%, B acc: 92.66%
# Epoch: [132/250], A Valid Acc: 89.60%, B Valid Acc: 94.50%
# Epoch: [133/250], Batch: [1/20], A_loss:0.1529, B_loss:0.1289
# Epoch: [133/250], A acc: 92.11%, B acc: 93.44%
# Epoch: [133/250], A Valid Acc: 87.16%, B Valid Acc: 91.74%
# Epoch: [134/250], Batch: [1/20], A_loss:0.1883, B_loss:0.1635
# Epoch: [134/250], A acc: 93.83%, B acc: 93.83%
# Epoch: [134/250], A Valid Acc: 87.46%, B Valid Acc: 92.66%
# Epoch: [135/250], Batch: [1/20], A_loss:0.2507, B_loss:0.1523
# Epoch: [135/250], A acc: 92.97%, B acc: 93.91%
# Epoch: [135/250], A Valid Acc: 90.52%, B Valid Acc: 93.27%
# Epoch: [136/250], Batch: [1/20], A_loss:0.2192, B_loss:0.1604
# Epoch: [136/250], A acc: 93.44%, B acc: 93.36%
# Epoch: [136/250], A Valid Acc: 89.30%, B Valid Acc: 93.27%
# Epoch: [137/250], Batch: [1/20], A_loss:0.0826, B_loss:0.1744
# Epoch: [137/250], A acc: 93.52%, B acc: 93.83%
# Epoch: [137/250], A Valid Acc: 91.13%, B Valid Acc: 95.72%
# Epoch: [138/250], Batch: [1/20], A_loss:0.1291, B_loss:0.2095
# Epoch: [138/250], A acc: 92.89%, B acc: 93.20%
# Epoch: [138/250], A Valid Acc: 87.16%, B Valid Acc: 92.97%
# Epoch: [139/250], Batch: [1/20], A_loss:0.1061, B_loss:0.1759
# Epoch: [139/250], A acc: 93.36%, B acc: 93.36%
# Epoch: [139/250], A Valid Acc: 90.21%, B Valid Acc: 92.97%
# Epoch: [140/250], Batch: [1/20], A_loss:0.2495, B_loss:0.1240
# Epoch: [140/250], A acc: 92.73%, B acc: 93.83%
# Epoch: [140/250], A Valid Acc: 90.21%, B Valid Acc: 95.11%
# Epoch: [141/250], Batch: [1/20], A_loss:0.1992, B_loss:0.1187
# Epoch: [141/250], A acc: 93.36%, B acc: 94.14%
# Epoch: [141/250], A Valid Acc: 89.60%, B Valid Acc: 93.88%
# Epoch: [142/250], Batch: [1/20], A_loss:0.1678, B_loss:0.0689
# Epoch: [142/250], A acc: 93.59%, B acc: 94.22%
# Epoch: [142/250], A Valid Acc: 89.60%, B Valid Acc: 94.50%
# Epoch: [143/250], Batch: [1/20], A_loss:0.1758, B_loss:0.1698
# Epoch: [143/250], A acc: 93.91%, B acc: 93.52%
# Epoch: [143/250], A Valid Acc: 90.21%, B Valid Acc: 95.11%
# Epoch: [144/250], Batch: [1/20], A_loss:0.2337, B_loss:0.1511
# Epoch: [144/250], A acc: 93.20%, B acc: 94.53%
# Epoch: [144/250], A Valid Acc: 89.60%, B Valid Acc: 94.19%
# Epoch: [145/250], Batch: [1/20], A_loss:0.2179, B_loss:0.1447
# Epoch: [145/250], A acc: 92.97%, B acc: 93.83%
# Epoch: [145/250], A Valid Acc: 89.91%, B Valid Acc: 94.80%
# Epoch: [146/250], Batch: [1/20], A_loss:0.1292, B_loss:0.1323
# Epoch: [146/250], A acc: 93.36%, B acc: 93.67%
# Epoch: [146/250], A Valid Acc: 90.21%, B Valid Acc: 94.19%
# Epoch: [147/250], Batch: [1/20], A_loss:0.1526, B_loss:0.1502
# Epoch: [147/250], A acc: 92.42%, B acc: 93.52%
# Epoch: [147/250], A Valid Acc: 89.91%, B Valid Acc: 95.41%
# Epoch: [148/250], Batch: [1/20], A_loss:0.1087, B_loss:0.1883
# Epoch: [148/250], A acc: 93.52%, B acc: 93.67%
# Epoch: [148/250], A Valid Acc: 89.60%, B Valid Acc: 93.88%
# Epoch: [149/250], Batch: [1/20], A_loss:0.1532, B_loss:0.0799
# Epoch: [149/250], A acc: 94.45%, B acc: 93.75%
# Epoch: [149/250], A Valid Acc: 91.44%, B Valid Acc: 94.19%
# Epoch: [150/250], Batch: [1/20], A_loss:0.1477, B_loss:0.1306
# Epoch: [150/250], A acc: 94.14%, B acc: 94.30%
# Epoch: [150/250], A Valid Acc: 86.85%, B Valid Acc: 89.30%
# Epoch: [151/250], Batch: [1/20], A_loss:0.4484, B_loss:0.1399
# Epoch: [151/250], A acc: 93.05%, B acc: 94.69%
# Epoch: [151/250], A Valid Acc: 90.83%, B Valid Acc: 93.88%
# Epoch: [152/250], Batch: [1/20], A_loss:0.1945, B_loss:0.1236
# Epoch: [152/250], A acc: 94.77%, B acc: 93.20%
# Epoch: [152/250], A Valid Acc: 90.21%, B Valid Acc: 94.80%
# Epoch: [153/250], Batch: [1/20], A_loss:0.1605, B_loss:0.2062
# Epoch: [153/250], A acc: 94.22%, B acc: 95.00%
# Epoch: [153/250], A Valid Acc: 90.52%, B Valid Acc: 92.97%
# Epoch: [154/250], Batch: [1/20], A_loss:0.2137, B_loss:0.1686
# Epoch: [154/250], A acc: 94.38%, B acc: 94.14%
# Epoch: [154/250], A Valid Acc: 90.21%, B Valid Acc: 95.11%
# Epoch: [155/250], Batch: [1/20], A_loss:0.0793, B_loss:0.1492
# Epoch: [155/250], A acc: 92.50%, B acc: 93.75%
# Epoch: [155/250], A Valid Acc: 92.35%, B Valid Acc: 91.44%
# Epoch: [156/250], Batch: [1/20], A_loss:0.2295, B_loss:0.1891
# Epoch: [156/250], A acc: 92.89%, B acc: 94.30%
# Epoch: [156/250], A Valid Acc: 90.21%, B Valid Acc: 94.80%
# Epoch: [157/250], Batch: [1/20], A_loss:0.0926, B_loss:0.1243
# Epoch: [157/250], A acc: 94.30%, B acc: 94.30%
# Epoch: [157/250], A Valid Acc: 88.69%, B Valid Acc: 94.19%
# Epoch: [158/250], Batch: [1/20], A_loss:0.2941, B_loss:0.1443
# Epoch: [158/250], A acc: 93.75%, B acc: 93.91%
# Epoch: [158/250], A Valid Acc: 91.13%, B Valid Acc: 91.74%
# Epoch: [159/250], Batch: [1/20], A_loss:0.1724, B_loss:0.1363
# Epoch: [159/250], A acc: 93.67%, B acc: 94.69%
# Epoch: [159/250], A Valid Acc: 87.16%, B Valid Acc: 92.05%
# Epoch: [160/250], Batch: [1/20], A_loss:0.1835, B_loss:0.1165
# Epoch: [160/250], A acc: 94.30%, B acc: 94.77%
# Epoch: [160/250], A Valid Acc: 91.44%, B Valid Acc: 94.19%
# Epoch: [161/250], Batch: [1/20], A_loss:0.1350, B_loss:0.2058
# Epoch: [161/250], A acc: 94.61%, B acc: 93.83%
# Epoch: [161/250], A Valid Acc: 90.21%, B Valid Acc: 94.50%
# Epoch: [162/250], Batch: [1/20], A_loss:0.1895, B_loss:0.1826
# Epoch: [162/250], A acc: 94.84%, B acc: 94.61%
# Epoch: [162/250], A Valid Acc: 89.60%, B Valid Acc: 94.19%
# Epoch: [163/250], Batch: [1/20], A_loss:0.1998, B_loss:0.1019
# Epoch: [163/250], A acc: 94.92%, B acc: 94.77%
# Epoch: [163/250], A Valid Acc: 90.21%, B Valid Acc: 91.13%
# Epoch: [164/250], Batch: [1/20], A_loss:0.1644, B_loss:0.1755
# Epoch: [164/250], A acc: 94.84%, B acc: 94.92%
# Epoch: [164/250], A Valid Acc: 90.52%, B Valid Acc: 93.88%
# Epoch: [165/250], Batch: [1/20], A_loss:0.1185, B_loss:0.1423
# Epoch: [165/250], A acc: 94.22%, B acc: 93.75%
# Epoch: [165/250], A Valid Acc: 89.60%, B Valid Acc: 94.50%
# Epoch: [166/250], Batch: [1/20], A_loss:0.1158, B_loss:0.0574
# Epoch: [166/250], A acc: 94.69%, B acc: 93.91%
# Epoch: [166/250], A Valid Acc: 89.91%, B Valid Acc: 94.50%
# Epoch: [167/250], Batch: [1/20], A_loss:0.1150, B_loss:0.2093
# Epoch: [167/250], A acc: 94.38%, B acc: 94.53%
# Epoch: [167/250], A Valid Acc: 90.52%, B Valid Acc: 94.50%
# Epoch: [168/250], Batch: [1/20], A_loss:0.0823, B_loss:0.1368
# Epoch: [168/250], A acc: 95.47%, B acc: 95.23%
# Epoch: [168/250], A Valid Acc: 90.21%, B Valid Acc: 94.19%
# Epoch: [169/250], Batch: [1/20], A_loss:0.1147, B_loss:0.0972
# Epoch: [169/250], A acc: 93.36%, B acc: 95.31%
# Epoch: [169/250], A Valid Acc: 90.21%, B Valid Acc: 92.35%
# Epoch: [170/250], Batch: [1/20], A_loss:0.1076, B_loss:0.0968
# Epoch: [170/250], A acc: 94.53%, B acc: 94.92%
# Epoch: [170/250], A Valid Acc: 88.07%, B Valid Acc: 94.19%
# Epoch: [171/250], Batch: [1/20], A_loss:0.0692, B_loss:0.1403
# Epoch: [171/250], A acc: 95.62%, B acc: 95.16%
# Epoch: [171/250], A Valid Acc: 90.21%, B Valid Acc: 94.19%
# Epoch: [172/250], Batch: [1/20], A_loss:0.1401, B_loss:0.0577
# Epoch: [172/250], A acc: 95.23%, B acc: 94.92%
# Epoch: [172/250], A Valid Acc: 90.21%, B Valid Acc: 94.19%
# Epoch: [173/250], Batch: [1/20], A_loss:0.1012, B_loss:0.1398
# Epoch: [173/250], A acc: 94.69%, B acc: 94.53%
# Epoch: [173/250], A Valid Acc: 89.60%, B Valid Acc: 93.88%
# Epoch: [174/250], Batch: [1/20], A_loss:0.1982, B_loss:0.1026
# Epoch: [174/250], A acc: 94.84%, B acc: 95.62%
# Epoch: [174/250], A Valid Acc: 90.21%, B Valid Acc: 94.19%
# Epoch: [175/250], Batch: [1/20], A_loss:0.1749, B_loss:0.1512
# Epoch: [175/250], A acc: 95.39%, B acc: 95.16%
# Epoch: [175/250], A Valid Acc: 91.13%, B Valid Acc: 92.66%
# Epoch: [176/250], Batch: [1/20], A_loss:0.1082, B_loss:0.1782
# Epoch: [176/250], A acc: 95.62%, B acc: 95.55%
# Epoch: [176/250], A Valid Acc: 90.52%, B Valid Acc: 95.41%
# Epoch: [177/250], Batch: [1/20], A_loss:0.1291, B_loss:0.0887
# Epoch: [177/250], A acc: 95.08%, B acc: 95.47%
# Epoch: [177/250], A Valid Acc: 90.52%, B Valid Acc: 94.80%
# Epoch: [178/250], Batch: [1/20], A_loss:0.2536, B_loss:0.1683
# Epoch: [178/250], A acc: 94.77%, B acc: 95.78%
# Epoch: [178/250], A Valid Acc: 87.16%, B Valid Acc: 94.19%
# Epoch: [179/250], Batch: [1/20], A_loss:0.1051, B_loss:0.1924
# Epoch: [179/250], A acc: 94.84%, B acc: 94.53%
# Epoch: [179/250], A Valid Acc: 90.83%, B Valid Acc: 95.11%
# Epoch: [180/250], Batch: [1/20], A_loss:0.1595, B_loss:0.1300
# Epoch: [180/250], A acc: 95.55%, B acc: 95.16%
# Epoch: [180/250], A Valid Acc: 87.77%, B Valid Acc: 91.74%
# Epoch: [181/250], Batch: [1/20], A_loss:0.1334, B_loss:0.1076
# Epoch: [181/250], A acc: 95.55%, B acc: 95.70%
# Epoch: [181/250], A Valid Acc: 90.52%, B Valid Acc: 94.80%
# Epoch: [182/250], Batch: [1/20], A_loss:0.0580, B_loss:0.0866
# Epoch: [182/250], A acc: 96.48%, B acc: 95.86%
# Epoch: [182/250], A Valid Acc: 90.21%, B Valid Acc: 94.80%
# Epoch: [183/250], Batch: [1/20], A_loss:0.1744, B_loss:0.1034
# Epoch: [183/250], A acc: 94.30%, B acc: 94.84%
# Epoch: [183/250], A Valid Acc: 85.63%, B Valid Acc: 91.13%
# Epoch: [184/250], Batch: [1/20], A_loss:0.2132, B_loss:0.0725
# Epoch: [184/250], A acc: 95.55%, B acc: 95.55%
# Epoch: [184/250], A Valid Acc: 91.74%, B Valid Acc: 95.41%
# Epoch: [185/250], Batch: [1/20], A_loss:0.1399, B_loss:0.0520
# Epoch: [185/250], A acc: 95.16%, B acc: 95.94%
# Epoch: [185/250], A Valid Acc: 91.44%, B Valid Acc: 94.19%
# Epoch: [186/250], Batch: [1/20], A_loss:0.1537, B_loss:0.0599
# Epoch: [186/250], A acc: 94.92%, B acc: 95.39%
# Epoch: [186/250], A Valid Acc: 90.21%, B Valid Acc: 94.80%
# Epoch: [187/250], Batch: [1/20], A_loss:0.0962, B_loss:0.1382
# Epoch: [187/250], A acc: 95.55%, B acc: 95.31%
# Epoch: [187/250], A Valid Acc: 88.99%, B Valid Acc: 94.50%
# Epoch: [188/250], Batch: [1/20], A_loss:0.1599, B_loss:0.1215
# Epoch: [188/250], A acc: 95.94%, B acc: 95.86%
# Epoch: [188/250], A Valid Acc: 91.44%, B Valid Acc: 94.50%
# Epoch: [189/250], Batch: [1/20], A_loss:0.1293, B_loss:0.0957
# Epoch: [189/250], A acc: 95.70%, B acc: 95.55%
# Epoch: [189/250], A Valid Acc: 89.91%, B Valid Acc: 94.50%
# Epoch: [190/250], Batch: [1/20], A_loss:0.0848, B_loss:0.0612
# Epoch: [190/250], A acc: 94.14%, B acc: 94.92%
# Epoch: [190/250], A Valid Acc: 90.83%, B Valid Acc: 88.07%
# Epoch: [191/250], Batch: [1/20], A_loss:0.1160, B_loss:0.1116
# Epoch: [191/250], A acc: 94.77%, B acc: 95.94%
# Epoch: [191/250], A Valid Acc: 91.74%, B Valid Acc: 95.11%
# Epoch: [192/250], Batch: [1/20], A_loss:0.2404, B_loss:0.1635
# Epoch: [192/250], A acc: 93.91%, B acc: 95.16%
# Epoch: [192/250], A Valid Acc: 92.35%, B Valid Acc: 93.58%
# Epoch: [193/250], Batch: [1/20], A_loss:0.1558, B_loss:0.1105
# Epoch: [193/250], A acc: 96.09%, B acc: 96.17%
# Epoch: [193/250], A Valid Acc: 88.99%, B Valid Acc: 95.41%
# Epoch: [194/250], Batch: [1/20], A_loss:0.0721, B_loss:0.0987
# Epoch: [194/250], A acc: 95.70%, B acc: 96.25%
# Epoch: [194/250], A Valid Acc: 90.21%, B Valid Acc: 94.19%
# Epoch: [195/250], Batch: [1/20], A_loss:0.1634, B_loss:0.0907
# Epoch: [195/250], A acc: 96.33%, B acc: 95.23%
# Epoch: [195/250], A Valid Acc: 92.35%, B Valid Acc: 92.66%
# Epoch: [196/250], Batch: [1/20], A_loss:0.1370, B_loss:0.0842
# Epoch: [196/250], A acc: 95.78%, B acc: 96.33%
# Epoch: [196/250], A Valid Acc: 90.21%, B Valid Acc: 95.41%
# Epoch: [197/250], Batch: [1/20], A_loss:0.1196, B_loss:0.1247
# Epoch: [197/250], A acc: 95.94%, B acc: 95.70%
# Epoch: [197/250], A Valid Acc: 91.44%, B Valid Acc: 94.19%
# Epoch: [198/250], Batch: [1/20], A_loss:0.1016, B_loss:0.0559
# Epoch: [198/250], A acc: 95.62%, B acc: 95.70%
# Epoch: [198/250], A Valid Acc: 88.69%, B Valid Acc: 95.41%
# Epoch: [199/250], Batch: [1/20], A_loss:0.1980, B_loss:0.0486
# Epoch: [199/250], A acc: 94.84%, B acc: 96.64%
# Epoch: [199/250], A Valid Acc: 91.74%, B Valid Acc: 94.19%
# Epoch: [200/250], Batch: [1/20], A_loss:0.0729, B_loss:0.0955
# Epoch: [200/250], A acc: 95.78%, B acc: 95.86%
# Epoch: [200/250], A Valid Acc: 90.21%, B Valid Acc: 90.52%
# Epoch: [201/250], Batch: [1/20], A_loss:0.0874, B_loss:0.2591
# Epoch: [201/250], A acc: 95.94%, B acc: 96.25%
# Epoch: [201/250], A Valid Acc: 91.13%, B Valid Acc: 95.41%
# Epoch: [202/250], Batch: [1/20], A_loss:0.1172, B_loss:0.0643
# Epoch: [202/250], A acc: 96.33%, B acc: 96.56%
# Epoch: [202/250], A Valid Acc: 90.52%, B Valid Acc: 94.80%
# Epoch: [203/250], Batch: [1/20], A_loss:0.1220, B_loss:0.0471
# Epoch: [203/250], A acc: 96.09%, B acc: 97.03%
# Epoch: [203/250], A Valid Acc: 91.44%, B Valid Acc: 95.11%
# Epoch: [204/250], Batch: [1/20], A_loss:0.1880, B_loss:0.0416
# Epoch: [204/250], A acc: 96.33%, B acc: 96.80%
# Epoch: [204/250], A Valid Acc: 90.83%, B Valid Acc: 95.41%
# Epoch: [205/250], Batch: [1/20], A_loss:0.0899, B_loss:0.0833
# Epoch: [205/250], A acc: 96.72%, B acc: 96.41%
# Epoch: [205/250], A Valid Acc: 88.99%, B Valid Acc: 94.80%
# Epoch: [206/250], Batch: [1/20], A_loss:0.0674, B_loss:0.0899
# Epoch: [206/250], A acc: 96.25%, B acc: 96.17%
# Epoch: [206/250], A Valid Acc: 89.60%, B Valid Acc: 93.27%
# Epoch: [207/250], Batch: [1/20], A_loss:0.0687, B_loss:0.1012
# Epoch: [207/250], A acc: 95.62%, B acc: 95.94%
# Epoch: [207/250], A Valid Acc: 90.52%, B Valid Acc: 94.80%
# Epoch: [208/250], Batch: [1/20], A_loss:0.2420, B_loss:0.1414
# Epoch: [208/250], A acc: 95.78%, B acc: 97.11%
# Epoch: [208/250], A Valid Acc: 90.83%, B Valid Acc: 92.66%
# Epoch: [209/250], Batch: [1/20], A_loss:0.1032, B_loss:0.1000
# Epoch: [209/250], A acc: 95.47%, B acc: 95.23%
# Epoch: [209/250], A Valid Acc: 90.21%, B Valid Acc: 92.35%
# Epoch: [210/250], Batch: [1/20], A_loss:0.0566, B_loss:0.0386
# Epoch: [210/250], A acc: 96.72%, B acc: 96.64%
# Epoch: [210/250], A Valid Acc: 91.74%, B Valid Acc: 94.80%
# Epoch: [211/250], Batch: [1/20], A_loss:0.1861, B_loss:0.0965
# Epoch: [211/250], A acc: 95.31%, B acc: 95.31%
# Epoch: [211/250], A Valid Acc: 88.38%, B Valid Acc: 92.05%
# Epoch: [212/250], Batch: [1/20], A_loss:0.1494, B_loss:0.1337
# Epoch: [212/250], A acc: 96.48%, B acc: 96.48%
# Epoch: [212/250], A Valid Acc: 92.35%, B Valid Acc: 94.50%
# Epoch: [213/250], Batch: [1/20], A_loss:0.0860, B_loss:0.1224
# Epoch: [213/250], A acc: 96.33%, B acc: 96.25%
# Epoch: [213/250], A Valid Acc: 92.05%, B Valid Acc: 94.80%
# Epoch: [214/250], Batch: [1/20], A_loss:0.0631, B_loss:0.0835
# Epoch: [214/250], A acc: 97.19%, B acc: 96.48%
# Epoch: [214/250], A Valid Acc: 91.44%, B Valid Acc: 94.80%
# Epoch: [215/250], Batch: [1/20], A_loss:0.0844, B_loss:0.0725
# Epoch: [215/250], A acc: 96.95%, B acc: 97.11%
# Epoch: [215/250], A Valid Acc: 92.05%, B Valid Acc: 94.80%
# Epoch: [216/250], Batch: [1/20], A_loss:0.0514, B_loss:0.0817
# Epoch: [216/250], A acc: 96.88%, B acc: 97.34%
# Epoch: [216/250], A Valid Acc: 90.52%, B Valid Acc: 94.80%
# Epoch: [217/250], Batch: [1/20], A_loss:0.0544, B_loss:0.0690
# Epoch: [217/250], A acc: 96.48%, B acc: 96.48%
# Epoch: [217/250], A Valid Acc: 91.13%, B Valid Acc: 95.11%
# Epoch: [218/250], Batch: [1/20], A_loss:0.1179, B_loss:0.1052
# Epoch: [218/250], A acc: 95.39%, B acc: 97.03%
# Epoch: [218/250], A Valid Acc: 92.05%, B Valid Acc: 93.27%
# Epoch: [219/250], Batch: [1/20], A_loss:0.0523, B_loss:0.0455
# Epoch: [219/250], A acc: 96.64%, B acc: 97.34%
# Epoch: [219/250], A Valid Acc: 88.69%, B Valid Acc: 93.88%
# Epoch: [220/250], Batch: [1/20], A_loss:0.0678, B_loss:0.0730
# Epoch: [220/250], A acc: 97.34%, B acc: 97.19%
# Epoch: [220/250], A Valid Acc: 89.91%, B Valid Acc: 92.35%
# Epoch: [221/250], Batch: [1/20], A_loss:0.0988, B_loss:0.1726
# Epoch: [221/250], A acc: 97.34%, B acc: 97.11%
# Epoch: [221/250], A Valid Acc: 92.97%, B Valid Acc: 94.80%
# Epoch: [222/250], Batch: [1/20], A_loss:0.1552, B_loss:0.1088
# Epoch: [222/250], A acc: 97.27%, B acc: 96.56%
# Epoch: [222/250], A Valid Acc: 89.60%, B Valid Acc: 94.80%
# Epoch: [223/250], Batch: [1/20], A_loss:0.0532, B_loss:0.0514
# Epoch: [223/250], A acc: 96.33%, B acc: 96.88%
# Epoch: [223/250], A Valid Acc: 88.99%, B Valid Acc: 94.19%
# Epoch: [224/250], Batch: [1/20], A_loss:0.1683, B_loss:0.0543
# Epoch: [224/250], A acc: 96.33%, B acc: 96.17%
# Epoch: [224/250], A Valid Acc: 90.83%, B Valid Acc: 92.66%
# Epoch: [225/250], Batch: [1/20], A_loss:0.2417, B_loss:0.1053
# Epoch: [225/250], A acc: 95.70%, B acc: 97.27%
# Epoch: [225/250], A Valid Acc: 91.13%, B Valid Acc: 94.80%
# Epoch: [226/250], Batch: [1/20], A_loss:0.0988, B_loss:0.0450
# Epoch: [226/250], A acc: 96.25%, B acc: 97.81%
# Epoch: [226/250], A Valid Acc: 92.35%, B Valid Acc: 95.11%
# Epoch: [227/250], Batch: [1/20], A_loss:0.0779, B_loss:0.0741
# Epoch: [227/250], A acc: 96.80%, B acc: 97.66%
# Epoch: [227/250], A Valid Acc: 88.69%, B Valid Acc: 92.35%
# Epoch: [228/250], Batch: [1/20], A_loss:0.1096, B_loss:0.0744
# Epoch: [228/250], A acc: 97.03%, B acc: 97.27%
# Epoch: [228/250], A Valid Acc: 92.05%, B Valid Acc: 92.66%
# Epoch: [229/250], Batch: [1/20], A_loss:0.1036, B_loss:0.1095
# Epoch: [229/250], A acc: 97.34%, B acc: 97.19%
# Epoch: [229/250], A Valid Acc: 91.44%, B Valid Acc: 95.11%
# Epoch: [230/250], Batch: [1/20], A_loss:0.1134, B_loss:0.0804
# Epoch: [230/250], A acc: 96.95%, B acc: 97.66%
# Epoch: [230/250], A Valid Acc: 90.52%, B Valid Acc: 93.58%
# Epoch: [231/250], Batch: [1/20], A_loss:0.1322, B_loss:0.0485
# Epoch: [231/250], A acc: 96.88%, B acc: 97.19%
# Epoch: [231/250], A Valid Acc: 90.21%, B Valid Acc: 95.11%
# Epoch: [232/250], Batch: [1/20], A_loss:0.1065, B_loss:0.0579
# Epoch: [232/250], A acc: 96.41%, B acc: 96.72%
# Epoch: [232/250], A Valid Acc: 90.83%, B Valid Acc: 94.80%
# Epoch: [233/250], Batch: [1/20], A_loss:0.0995, B_loss:0.0563
# Epoch: [233/250], A acc: 96.80%, B acc: 97.34%
# Epoch: [233/250], A Valid Acc: 92.97%, B Valid Acc: 94.80%
# Epoch: [234/250], Batch: [1/20], A_loss:0.0481, B_loss:0.0294
# Epoch: [234/250], A acc: 97.42%, B acc: 97.50%
# Epoch: [234/250], A Valid Acc: 89.30%, B Valid Acc: 95.11%
# Epoch: [235/250], Batch: [1/20], A_loss:0.1152, B_loss:0.0921
# Epoch: [235/250], A acc: 97.19%, B acc: 96.95%
# Epoch: [235/250], A Valid Acc: 91.44%, B Valid Acc: 94.80%
# Epoch: [236/250], Batch: [1/20], A_loss:0.0983, B_loss:0.0972
# Epoch: [236/250], A acc: 96.25%, B acc: 97.42%
# Epoch: [236/250], A Valid Acc: 91.13%, B Valid Acc: 92.66%
# Epoch: [237/250], Batch: [1/20], A_loss:0.0778, B_loss:0.0541
# Epoch: [237/250], A acc: 97.50%, B acc: 97.97%
# Epoch: [237/250], A Valid Acc: 92.66%, B Valid Acc: 95.11%
# Epoch: [238/250], Batch: [1/20], A_loss:0.1027, B_loss:0.0751
# Epoch: [238/250], A acc: 97.19%, B acc: 97.89%
# Epoch: [238/250], A Valid Acc: 92.97%, B Valid Acc: 92.97%
# Epoch: [239/250], Batch: [1/20], A_loss:0.0981, B_loss:0.0650
# Epoch: [239/250], A acc: 96.02%, B acc: 97.19%
# Epoch: [239/250], A Valid Acc: 90.21%, B Valid Acc: 94.50%
# Epoch: [240/250], Batch: [1/20], A_loss:0.1052, B_loss:0.1402
# Epoch: [240/250], A acc: 96.33%, B acc: 97.66%
# Epoch: [240/250], A Valid Acc: 87.77%, B Valid Acc: 95.11%
# Epoch: [241/250], Batch: [1/20], A_loss:0.1263, B_loss:0.0455
# Epoch: [241/250], A acc: 96.56%, B acc: 97.19%
# Epoch: [241/250], A Valid Acc: 90.52%, B Valid Acc: 91.13%
# Epoch: [242/250], Batch: [1/20], A_loss:0.1348, B_loss:0.1240
# Epoch: [242/250], A acc: 96.95%, B acc: 96.72%
# Epoch: [242/250], A Valid Acc: 89.91%, B Valid Acc: 95.11%
# Epoch: [243/250], Batch: [1/20], A_loss:0.1584, B_loss:0.0426
# Epoch: [243/250], A acc: 97.27%, B acc: 97.73%
# Epoch: [243/250], A Valid Acc: 92.35%, B Valid Acc: 94.50%
# Epoch: [244/250], Batch: [1/20], A_loss:0.1164, B_loss:0.0946
# Epoch: [244/250], A acc: 97.50%, B acc: 97.03%
# Epoch: [244/250], A Valid Acc: 92.05%, B Valid Acc: 94.50%
# Epoch: [245/250], Batch: [1/20], A_loss:0.0961, B_loss:0.0603
# Epoch: [245/250], A acc: 97.89%, B acc: 97.89%
# Epoch: [245/250], A Valid Acc: 92.05%, B Valid Acc: 94.50%
# Epoch: [246/250], Batch: [1/20], A_loss:0.1190, B_loss:0.0547
# Epoch: [246/250], A acc: 97.42%, B acc: 98.20%
# Epoch: [246/250], A Valid Acc: 92.66%, B Valid Acc: 94.50%
# Epoch: [247/250], Batch: [1/20], A_loss:0.0795, B_loss:0.0648
# Epoch: [247/250], A acc: 97.81%, B acc: 97.19%
# Epoch: [247/250], A Valid Acc: 90.83%, B Valid Acc: 94.50%
# Epoch: [248/250], Batch: [1/20], A_loss:0.0776, B_loss:0.0413
# Epoch: [248/250], A acc: 97.66%, B acc: 97.89%
# Epoch: [248/250], A Valid Acc: 92.05%, B Valid Acc: 94.80%
# Epoch: [249/250], Batch: [1/20], A_loss:0.0736, B_loss:0.0316
# Epoch: [249/250], A acc: 97.58%, B acc: 98.05%
# Epoch: [249/250], A Valid Acc: 91.13%, B Valid Acc: 92.35%
# Epoch: [250/250], Batch: [1/20], A_loss:0.0746, B_loss:0.0775
# Epoch: [250/250], A acc: 97.58%, B acc: 96.48%
# Epoch: [250/250], A Valid Acc: 89.30%, B Valid Acc: 94.80%

# %% [markdown]
# ### Evaluate on Test Dataset

# %%
extractor = AccExtractor().to(DEVICE)
classifier_A = AccClassifier(output_gt_number).to(DEVICE)
classifier_B = AccClassifier(output_gt_number).to(DEVICE)

extractor.load_state_dict(torch.load(feature_save_path))
classifier_A.load_state_dict(torch.load(classifier_A_save_path))
classifier_B.load_state_dict(torch.load(classifier_B_save_path))

extractor.eval()
classifier_A.eval()
classifier_B.eval()

print("Evaluating...")
target_loader = test_load(Target, Target_GT, batch_size=64)


A_correct = 0
B_correct = 0
A_total = 0
B_total = 0

accuracy = []
for t_sample, t_target in target_loader:

    t_sample, t_target = t_sample.to(DEVICE).float(), t_target.to(DEVICE).long()
    t_sample = t_sample.view(-1, AXIS, 1, 128)


    feature = extractor(t_sample)
    A_output = classifier_A(feature)
    B_output = classifier_B(feature)

    _, A_predicted = torch.max(A_output.data, 1)
    A_total += t_target.size(0)
    A_correct += (A_predicted == t_target).sum()

    _, B_predicted = torch.max(B_output.data, 1)
    B_total += t_target.size(0)
    B_correct += (B_predicted == t_target).sum()

acc_test_A = float(A_correct) * 100 / A_total
acc_test_B = float(B_correct) * 100 / B_total
tqdm.tqdm.write('A Test Acc: {:.2f}%'.format(acc_test_A))
tqdm.tqdm.write('B Test Acc: {:.2f}%'.format(acc_test_B))
# accuracy.append([acc_test_A, acc_test_B])
# accuracy_np = np.array(accuracy, dtype=float)
# np.savetxt('Accuracy.csv', accuracy_np, fmt='%.2f', delimiter=',')
# Out:
# Evaluating...
# A Test Acc: 42.23%
# B Test Acc: 51.75%
