# %% [markdown]
# # Access the Processed (IMU+Mag+Index of each segment of 128 Hz) IMU Data File
# # Access the Shot Segment Information
# # Extract the Labeled Short Segments

# %%
# use annotation file to extract the active data points
import matplotlib as plt
import pandas as pd
import os
import numpy as np
import math
import csv

# %%
home_url = os.getcwd()
elan_url = os.path.abspath(os.path.join(home_url, '..', 'ELAN File'))
segment_info_url = os.path.abspath(os.path.join(home_url, '..', 'Segment Information'))
extracted_data_url = os.path.abspath(os.path.join(home_url, '..', 'Extracted Data Files'))

P1_file = "P1.csv"
P2_file = "P2-P3.csv"
P3_file = "P2-P3.csv"
P4_file = "P4.csv"

# %%
segment_info_url
# Out:
# '/home/avijoy/Downloads/Penalty Shoot-out Github/Segment Information'

# %%
P1_df = pd.read_csv(elan_url + "/" + P1_file)
P2_df = pd.read_csv(elan_url + "/" + P2_file)
P3_df = pd.read_csv(elan_url + "/" + P3_file)
P4_df = pd.read_csv(elan_url + "/" + P4_file)

# %% [markdown]
# ## Shot Segment Information

# %%
P1_annotation = "P1.txt"
P2_annotation = "P2.txt"
P3_annotation = "P3.txt"
P4_annotation = "P4.txt"

# %%
list(P1_df)
# Out:
# ['Unnamed: 0',
#  'Timestamp',
#  'Accelerometer X',
#  'Accelerometer Y',
#  'Accelerometer Z',
#  'value',
#  'New Index']

# %% [markdown]
# ## Replace the Column Name

# %%
P1_df.rename(columns={'Unnamed: 0': 'Index', 'Accelerometer X': 'X', 'Accelerometer Y': 'Y', 'Accelerometer Z': 'Z'}, inplace=True)
P2_df.rename(columns={'Unnamed: 0': 'Index', 'Accelerometer X': 'X', 'Accelerometer Y': 'Y', 'Accelerometer Z': 'Z'}, inplace=True)
P3_df.rename(columns={'Unnamed: 0': 'Index', 'Accelerometer X': 'X', 'Accelerometer Y': 'Y', 'Accelerometer Z': 'Z'}, inplace=True)
P4_df.rename(columns={'Unnamed: 0': 'Index', 'Accelerometer X': 'X', 'Accelerometer Y': 'Y', 'Accelerometer Z': 'Z'}, inplace=True)

# %% [markdown]
# ## Remove Redundant Columns

# %%
P1_df.drop(['Timestamp', 'value', 'New Index'], axis=1, inplace=True)
P2_df.drop(['Timestamp', 'value', 'New Index'], axis=1, inplace=True)
P3_df.drop(['Timestamp', 'value', 'New Index'], axis=1, inplace=True)
P4_df.drop(['Timestamp', 'value', 'New Index'], axis=1, inplace=True)

# %% [markdown]
# ## Read Annotation and Create Separate Dataframe File
#     - Tokenize each shot(data) entry
#     - Aggregate different shots in different dataframes

# %%
# Read the text file
def read_annotation_file(df, file_name, user):
    lg_df = pd.DataFrame(columns=['X','Y','Z'])
    lt_df = pd.DataFrame(columns=['X','Y','Z'])
    rg_df = pd.DataFrame(columns=['X','Y','Z'])
    rt_df = pd.DataFrame(columns=['X','Y','Z'])
    mg_df = pd.DataFrame(columns=['X','Y','Z'])
    mt_df = pd.DataFrame(columns=['X','Y','Z'])

    annotation_file = open(file_name)
    for line in annotation_file:
#         print(line)
        tokens = line.split()
        start = int(tokens[4])+1
        end = int(tokens[7])+1
        
        item_df = df[start:end]
        if (tokens[0] == 'LG'):
            lg_df = pd.concat([lg_df,item_df], sort=True, axis = 0)
        elif (tokens[0] == 'LT'):
            lt_df = pd.concat([lt_df,item_df], sort=True, axis = 0)
        elif (tokens[0] == 'RG'):
            rg_df = pd.concat([rg_df,item_df], sort=True, axis = 0)
        elif (tokens[0] == 'RT'):
            rt_df = pd.concat([rt_df,item_df], sort=True, axis = 0)
        elif (tokens[0] == 'MG'):
            mg_df = pd.concat([mg_df,item_df], sort=True, axis = 0)
        elif (tokens[0] == 'MT'):
            mt_df = pd.concat([mt_df,item_df], sort=True, axis = 0)
    annotation_file.close()
    
    lg_df['Label'] = 0
    lt_df['Label'] = 1
    rg_df['Label'] = 2
    rt_df['Label'] = 3
    mg_df['Label'] = 4
    mt_df['Label'] = 5
    
    final_df = pd.concat([lg_df, lt_df, rg_df, rt_df, mg_df, mt_df], sort=True, axis = 0)
    final_df['User'] = user
    final_df.to_csv(extracted_data_url+ "/" + str(user)+'_raw_labeled.csv', float_format='%.6f')

# %%
read_annotation_file(P1_df, segment_info_url + "/" + P1_annotation, "P1")
read_annotation_file(P2_df, segment_info_url + "/" + P2_annotation, "P2")
read_annotation_file(P3_df, segment_info_url + "/" + P3_annotation, "P3")
read_annotation_file(P4_df, segment_info_url + "/" + P4_annotation, "P4")
# Out:
# RG RG start = 304380 end = 304465
#
# RG RG start = 306845 end = 306910
#
# RG MG start = 308755 end = 308855
#
# RG RG start = 310930 end = 311045 [Sensor Came out. Noise Data]
#
# RG Miss start = 316833 end = 316930
#
# RG MG start = 319355 end = 319426
#
# RG RG start = 321499 end = 321610
#
# RG RG start = 323585 end = 323690
#
# RG RG start = 325715 end = 325825
#
# RG PM start = 327809 end = 327880
#
# RG RG start = 330780 end = 330855
#
# RT RT start = 333190 end = 333295
#
# RT Miss start = 335610 end = 335725
#
# RT RT start = 337940 end = 338040
#
# RT Miss start = 342545 end = 342655
#
# RT RT start = 345010 end = 345125
#
# RT Miss start = 347415 end = 347505
#
# RT Miss start = 350305 end = 350395
#
# RT RT start = 352810 end = 352900
#
# RT RT start = 354870 end = 354970
#
# RT Miss start = 357320 end = 357425
#
# RT RT start = 359810 end = 359925
#
# RT RT start = 362520 end = 362630
#
# RT Miss start = 364950 end = 365055
#
# RT RT start = 367930 end = 368035
#
# LG LM start = 374665 end = 374720
#
# LG MT start = 376330 end = 376420
#
# LG LG start = 378220 end = 378270
#
# LG LG start = 379940 end = 379990
#
# LG LG start = 382085 end = 382150
#
# LG LG start = 384340 end = 384400
#
# LG LG start = 386610 end = 386665
#
# LG LM start = 388760 end = 388820
#
# LG MM start = 390905 end = 390955
#
# LG LG start = 392925 end = 392985
#
# LT LG start = 395205 end = 395260
#
# LT PM start = 397495 end = 397545
#
# LT LT start = 399030 end = 399125
#
# LT MM start = 401138 end = 401235
#
# LT MT start = 402940 end = 403038
#
# LT LT start = 404740 end = 404860
#
# LT PO start = 406650 end = 406770
#
# LT Miss start = 409170 end = 409270
#
# LT LT start = 411290 end = 411400
#
# LT MT start = 413220 end = 413320
#
# LT LT start = 415280 end = 415365
#
# LT LT start = 417320 end = 417450
#
# LT LM start = 420010 end = 420120
#
# LT LM start = 421900 end = 421955
#
# LT MM start = 424390 end = 424500
#
# LT LT start = 426320 end = 426420
#
# MG LG start = 428720 end = 428810
#
# MG MG start = 430820 end = 430880
#
# MG MG start = 433105 end = 433200
#
# MG MM start = 435575 end = 435650
#
# MG MG start = 439440 end = 439515
#
# MG MG start = 443650 end = 443725
#
# MG MT start = 447490 end = 447530
#
# MG MM start = 449060 end = 449115
#
# MG MM start = 451500 end = 451590
#
# MT MM start = 453925 end = 453995
#
# MT MT start = 455705 end = 455765
#
# MT MT start = 457430 end = 457499
#
# MT MT start = 459200 end = 459260
#
# MT MT start = 461025 end = 461080
#
# MT MT start = 463210 end = 463305
#
# MT MT start = 465665 end = 465740
#
# MT LT start = 468415 end = 468470
#
# RG RG start = 343670 end = 343740
#
# RG RG start = 345930 end = 346005
#
# RG RM start = 348170 end = 348235
#
# RG MG start = 350432 end = 350500
#
# RG PM start = 352845 end = 352915
#
# RG RG start = 355995 end = 356065
#
# RG RG start = 358525 end = 358605
#
# RG RG start = 360623 end = 360680
#
# RG RG start = 363290 end = 363345
#
# RG PM start = 366165 end = 366230
#
# RG MG start = 370040 end = 370100
#
# RT RT start = 374850 end = 374910
#
# RT RG start = 377340 end = 377400 [Fast paced]
#
# RT RT start = 379960 end = 380035
#
# RT Miss start = 382280 end = 382340
#
# RT RT start = 385625 end = 385705
#
# RT RT start = 387630 end = 387705
#
# RT RT start = 390135 end = 390205
#
# RT Miss start = 392195 end = 392285
#
# RT RT start = 396370 end = 396450
#
# RT RT start = 398265 end = 398350
#
# RT RT start = 400710 end = 400805
#
# LG LG start = 409170 end = 409260
#
# LG LG start = 411845 end = 411920
#
# LG LG start = 414365 end = 414450
#
# LG LM start = 416780 end = 416880
#
# LG LG start = 419095 end = 419200
#
# LG LT start = 421475 end = 421570
#
# LG LG start = 423540 end = 423630
#
# LG LG start = 425750 end = 425850
#
# LG Miss start = 428335 end = 428440
#
# LG LG start = 430565 end = 430665
#
# LT PM start = 433220 end = 433305
#
# LT LM start = 435010 end = 435105
#
# LT LG start = 437390 end = 437490
#
# LT Miss start = 440122 end = 440215 [Above post]
#
# LT Miss start = 442335 end = 442425
#
# LT LM start = 446165 end = 446275
#
# LT LT start = 449580 end = 449680
#
# LT Miss start = 452175 end = 452280 [Above post]
#
# LT LT start = 455515 end = 455660
#
# LT LT start = 458295 end = 458425
#
# LT LM start = 461115 end = 461190
#
# MG MG start = 463140 end = 463230
#
# MG MM start = 465645 end = 465720
#
# MG MM start = 467580 end = 467670
#
# MG MM start = 470155 end = 470245
#
# MG MG start = 472305 end = 472395
#
# MG MG start = 474275 end = 474355
#
# MG MM start = 477025 end = 477125
#
# MG MG start = 479070 end = 479150
#
# MG MM start = 480855 end = 480930
#
# MG MG start = 483360 end = 483460
#
# MT MG start = 486560 end = 486650 [Power shot]
#
# MT PM start = 488910 end = 489010
#
# MT LG start = 491390 end = 491470
#
# MT MM start = 493900 end = 493990
#
# MT MM start = 496240 end = 496350
#
# MT MM start = 499030 end = 499160
#
# MT MG start = 501050 end = 501150 [Power]
#
# MT MT start = 503780 end = 503930
#
# MT MT start = 505635 end = 505755
#
# MT Miss start = 507390 end = 507500 [Above post]
#
# RG RM start = 274827 end = 274885
#
# RG RG start = 277133 end = 277198
#
# RG RM start = 279285 end = 279348
#
# RG PMO start = 281120 end = 281175
#
# RG RG start = 283275 end = 283335
#
# RG Miss start = 285325 end = 285385
#
# RG RG start = 288125 end = 288185
#
# RG RG start = 289880 end = 289960
#
# RG RG start = 292035 end = 292105
#
# RG RG start = 293990 end = 294070
#
# RG RG start = 296465 end = 296535
#
# RG RG start = 296470 end = 296550
#
# RG RG start = 298825 end = 298885
#
# RT RT start = 301435 end = 301530
#
# RT RT start = 303860 end = 303960
#
# RT RT start = 305980 end = 306070
#
# RT RT start = 309010 end = 309110
#
# RT RT start = 311135 end = 311225
#
# RT RM start = 312485 end = 312560
#
# RT RT start = 314435 end = 314530
#
# RT RT start = 316680 end = 316770
#
# RT RT start = 318585 end = 318670
#
# RT Miss start = 320900 end = 320990
#
# RT RM start = 323400 end = 323485
#
# RT RT start = 325860 end = 325950
#
# LG LM start = 327735 end = 327810
#
# LG LM start = 330380 end = 330440
#
# LG LG start = 332580 end = 332645
#
# LG LG start = 334735 end = 334800
#
# LG LG start = 336940 end = 337000
#
# LG LG start = 338830 end = 338895
#
# LG LM start = 341030 end = 341100
#
# LG LM start = 343745 end = 343810
#
# LG LM start = 345880 end = 345950
#
# LG LG start = 348440 end = 348510
#
# LG LG start = 350730 end = 350800
#
# LG LG start = 352985 end = 353050
#
# LT LT start = 355480 end = 355580
#
# LT LT start = 357310 end = 357430
#
# LT LT start = 359715 end = 359785
#
# LT LT start = 361820 end = 361900
#
# LT Miss start = 364355 end = 364440
#
# LT LT start = 366865 end = 366945
#
# LT LT start = 369145 end = 369245
#
# LT LM start = 371205 end = 371285
#
# LT LT start = 373225 end = 373320
#
# LT LT start = 375340 end = 375420
#
# LT LM start = 377310 end = 377395
#
# LT LM start = 379580 end = 379670
#
# LT LT start = 382160 end = 382240
#
# MG MG start = 385195 end = 385250
#
# MG MG start = 387140 end = 387200
#
# MG MG start = 389090 end = 389160
#
# MG MG start = 391230 end = 391288
#
# MG MG start = 393305 end = 393365
#
# MG MG start = 395220 end = 395280
#
# MG MG start = 397585 end = 397635
#
# MG MG start = 399460 end = 399530
#
# MG MG start = 401220 end = 401290
#
# MG MG start = 403395 end = 403450
#
# MT MT start = 408785 end = 408865
#
# MT MT start = 410495 end = 410585
#
# MT MT start = 413135 end = 413220
#
# MT MT start = 414880 end = 414960
#
# MT MT start = 416695 end = 416770
#
# MT MT start = 418810 end = 418890
#
# MT MT start = 420907 end = 420980
#
# MT MT start = 423505 end = 423595
#
# MT MT start = 425314 end = 425405
#
# MT MM start = 427125 end = 427205
#
# RG RG start = 465215 end = 465290
#
# RG RG start = 467000 end = 467080
#
# RG RG start = 468780 end = 468840
#
# RG RG start = 470750 end = 470820
#
# RG RG start = 472920 end = 472990
#
# RG RG start = 474855 end = 474925
#
# RG RG start = 476770 end = 476840
#
# RG RG start = 478790 end = 478860
#
# RG RG start = 481623 end = 481690
#
# RG RG start = 483285 end = 483355
#
# RT RM start = 485880 end = 485945
#
# RT RM start = 487815 end = 487875
#
# RT RT start = 490040 end = 490100
#
# RT RT start = 491780 end = 491845
#
# RT RT start = 493710 end = 493785
#
# RT RT start = 495600 end = 495660
#
# RT RT start = 497465 end = 497525
#
# RT RT start = 499192 end = 499255
#
# RT RT start = 500450 end = 500510
#
# RT RM start = 503252 end = 503305
#
# RT Miss start = 506178 end = 506235
#
# LG LG start = 511300 end = 511352
#
# LG LG start = 513220 end = 513260
#
# LG LG start = 514985 end = 515020
#
# LG Miss start = 516380 end = 516415
#
# LG LG start = 520410 end = 520470
#
# LG LG start = 522470 end = 522515
#
# LG LG start = 524487 end = 524535
#
# LG LG start = 526325 end = 526385
#
# LG LG start = 528332 end = 528390
#
# LG LG start = 530030 end = 530105
#
# LT PM start = 534380 end = 534445
#
# LT LT start = 535980 end = 536050
#
# LT LT start = 537460 end = 537540
#
# LT LT start = 539030 end = 539095
#
# LT LT start = 540840 end = 540905
#
# LT LT start = 542405 end = 542480
#
# LT LT start = 544275 end = 544345
#
# LT LT start = 545795 end = 545865
#
# LT Miss start = 547190 end = 547260
#
# LT LT start = 549740 end = 549810
#
# MG MG start = 551245 end = 551305
#
# MG MG start = 552993 end = 553052
#
# MG MG start = 554943 end = 555003
#
# MG MG start = 556741 end = 556798
#
# MG MG start = 558395 end = 558460
#
# MG MG start = 560035 end = 560105
#
# MG MG start = 562032 end = 562100
#
# MG RG start = 563755 end = 563830
#
# MG MG start = 568412 end = 568470
#
# MG MG start = 570865 end = 570928
#
# MT MM start = 573810 end = 573890
#
# MT MT start = 577090 end = 577155
#
# MT MM start = 578530 end = 578610
#
# MT MM start = 580555 end = 580625
#
# MT MT start = 582250 end = 582320
#
# MT MT start = 583905 end = 583975
#
# MT MT start = 585400 end = 585470
#
# MT PO start = 587065 end = 587130
#
# MT PM start = 588375 end = 588440
#
# MT MT start = 590625 end = 590705
#
# MT MM start = 592010 end = 592080
#
# MT MT start = 593580 end = 593645
#
# MT MT start = 594895 end = 594965
#
# MT MM start = 596210 end = 596280
#
# MT MT start = 597975 end = 598040
